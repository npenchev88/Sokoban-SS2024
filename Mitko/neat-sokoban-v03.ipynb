# %% [markdown]
# How to create the environment (replace neat_test4 with your env name):
#
# - conda create -n neat_test4 python=3.10 gym ipykernel pyglet
# - conda activate neat_test4
# - pip install neat-python
# - pip install -e "<path_to_gym_location>\gym-sokoban"
# - python -m ipykernel install --user --name neat_test4 --display-name "Python (neat_test4)"
# - pip install graphviz

# %% [markdown]
# ### Initial setups

# %%
import neat
import gym
import gym_sokoban
import pyglet
from pyglet import clock
import numpy as np
import pickle
import time
import logging
from neat.reporting import StdOutReporter
import random
import visualize
import graphviz
import os

# %%
## Custom rendering setup if gym's rendering is not available
class Viewer:
    def __init__(self, width, height):
        self.window = pyglet.window.Window(width, height)
        self.image = None
        self.window.on_draw = self.on_draw

    def render(self, image):
        self.image = pyglet.image.ImageData(image.shape[1], image.shape[0], 'RGB', image.tobytes(), pitch=image.shape[1] * -3)
        self.window.dispatch_event('on_draw')

    def on_draw(self):
        if self.image:
            self.window.clear()
            self.image.blit(0, 0)

# %%
# Custom reporter class
class CustomReporter(StdOutReporter):
    def __init__(self, show_species_detail, config_filename):
        super().__init__(show_species_detail)
        self.start_time = time.time()
        self.config_filename = config_filename
    
    def end(self):
        runtime = time.time() - self.start_time
        logging.info(f'Total runtime: {runtime:.2f} seconds')
    
    def post_evaluate(self, config, population, species_set, best_genome):
        super().post_evaluate(config, population, species_set, best_genome)
        
        # Log population's average fitness
        total_fitness = sum(genome.fitness for genome in population.values())
        avg_fitness = total_fitness / len(population)
        logging.info(f'Population\'s average fitness: {avg_fitness}')
        
        # Log adjusted fitness score
        adjusted_fitness = []
        for species_id, species in species_set.species.items():
            for genome_id in species.members:
                genome = population[genome_id]
                adjusted_fitness.append(genome.fitness / len(species.members))
        avg_adjusted_fitness = sum(adjusted_fitness) / len(adjusted_fitness)
        logging.info(f'Population\'s average adjusted fitness: {avg_adjusted_fitness}')
        
        # Log best genome information
        logging.info(f'\nBest genome:\nKey: {best_genome.key}\nFitness: {best_genome.fitness}')
        logging.info(f'Nodes:')
        for node_key, node in best_genome.nodes.items():
            logging.info(f'\t{node_key} {node}')
        logging.info(f'Connections:')
        for conn_key, conn in best_genome.connections.items():
            logging.info(f'\t{conn_key} {conn}')
        
        # Log configuration file content
        if self.config_filename:
            try:
                with open(self.config_filename, 'r') as f:
                    config_content = f.read()
                    logging.info(f'Config File:\n{config_content}')
            except FileNotFoundError:
                logging.warning(f'Config file "{self.config_filename}" not found.')

        # Log timestamp
        logging.info(f'Timestamp: {time.strftime("%Y-%m-%d %H:%M:%S")}')

# %%
# Initialize logging
logging.basicConfig(filename='neat_log.txt', level=logging.INFO, format='%(message)s')

# %% [markdown]
# #### Configs

# %%
# Load configuration.
config_filename = 'config-feedforward_v03'
config = neat.Config(neat.DefaultGenome, 
                     neat.DefaultReproduction, 
                     neat.DefaultSpeciesSet, 
                     neat.DefaultStagnation, 
                     config_filename)

# Check if a checkpoint exists
checkpoint_file = r'D:\Education\AI\Machine_Learning_Practice\Summer School 2024\Sokoban-SS2024\NEAT\run_config_03\neat-checkpoint-v03-123'  # Replace with your checkpoint filename

if os.path.isfile(checkpoint_file):
    # Load the checkpoint
    p = neat.Checkpointer.restore_checkpoint(checkpoint_file)
else:
    # Create the population if no checkpoint exists
    p = neat.Population(config)

# Add reporters to show progress in the terminal and log to file.
p.add_reporter(neat.StdOutReporter(True))
custom_reporter = CustomReporter(True, config_filename)
p.add_reporter(custom_reporter)
stats = neat.StatisticsReporter()
p.add_reporter(stats)
p.add_reporter(neat.Checkpointer(1, filename_prefix='neat-checkpoint-v03-'))

file_name = 'winner_test_03.pkl'


# Define episode and timestep parameters
num_episodes = 1
timesteps_per_episode = 40

current_episode = 0
current_timestep = 0

min_reward = -10

# param used to mutate a step
epsilon = 0.05

# %% [markdown]
# ### Classes and methods

# %% [markdown]
# #### Preprocessing inputs/outputs

# %%
def process_observation(environment, obs):
        
    # Convert the observation to RGB frame or custom observation
    arr_walls, arr_goals, arr_boxes, arr_player = environment.render(mode='raw')

    # Initialize the combined array with walls (1s)
    combined = np.ones_like(arr_walls)
    
    # Set empty fields (0s)
    combined[arr_walls == 0] = 0
    
    # Set targets (3s)
    combined[arr_goals == 1] = 3
    
    # Set boxes (2s)
    combined[arr_boxes == 1] = 2
    
    # Set boxes on targets (4s)
    combined[(arr_boxes == 1) & (arr_goals == 1)] = 4
    
    # Set player position (5s)
    combined[arr_player == 1] = 5

    # Flatten the array
    flat_array = combined.flatten()
    
#     print("Flat array: ", flat_array)
#     print("Flat array shape: ", flat_array.shape)

    # Output the flattened array
    return flat_array



def process_state(state):
# Processes the initial state of env.reset()


    # Initialize the combined array with walls (0s)
    combined = np.ones_like(state[0])
    
    # Set empty fields (1s)
    combined[state[0] == 0] = 0

    # Set targets (3s)
    combined[state[1] == 1] = 3

    # Set boxes (2s)
    combined[state[2] == 1] = 2

    # Set boxes on targets (4s)
    combined[(state[2] == 1) & (state[1] == 1)] = 4

    # Set player position (5s)
    combined[state[3] == 1] = 5

    # Flatten the array
    flat_array = combined.flatten()
    
#     print("Flat array: ", flat_array)
#     print("Flat array shape: ", flat_array.shape)

    # Output the flattened array
    return flat_array

# %%
def map_action(output):
    return np.argmax(output)

# %% [markdown]
# ### Run Neat logic

# %%
# Start the game
env = gym.make('Sokoban-small-v1')
# generate the level in the initial stage (env.reset) 
env.reset()


# # OPTIONAL
viewer = Viewer(160, 160)  # Adjust the size according to your environment
ACTION_LOOKUP = env.unwrapped.get_action_lookup()



def eval_genomes(genomes, config):

    global num_episodes, timesteps_per_episode, current_episode, current_timestep, min_reward

    # FOR EACH GENOME
    for genome_id, genome in genomes:
               
        # generate the neural network based on the config provided
        net = neat.nn.FeedForwardNetwork.create(genome, config)
    
        # define the initial fitness of the genome
        genome.fitness = 0.0
    
        # define episodes rewards (list) idea is to keep the fitness scores of all episodes and take the max
        episodes_rewards = []
        
        # FOR EACH EPISODE
        for episode in range(num_episodes):
            
            # Episode reward = 0  
            ep_reward = 0
            
            # reset the game state to the initial phase
            initial_state = env.reset()

            # map inputs suitable for the Neural Network (initial state of the game as flatten array, e.g. with length 49, created by the initial 7x7 grid)
            # used as an input layer in the Neural Network
            initial_inputs = process_state(initial_state)
            
            game_state_after_step = initial_inputs
            
            # FOR EACH STEP
            for step in range(timesteps_per_episode):
                
               
                # calculate probabilities for each output to be selected
                action_prob = net.activate(game_state_after_step)
                
                # select the action, based on the output's probabilities of being selected
                action = map_action(action_prob)
                
                # ADD CUSTOM MUTATION IN THE STEPS (at a random event, the alg could chose a random step)
                
                if random.random() < epsilon:
                    action = env.action_space.sample()
                else:
                    # select the action, based on the output's probabilities of being selected
                    action = map_action(action_prob)
                
#                 # RANDOM ACTION (replace with the genome)
#                 action = env.action_space.sample()

                # make the move in the game and output game state + info + reward
                observation, reward, done, info = env.step(action)
                
#                 # TODO (MAYBE) !!!! Adjust the fitness function
                
#                 # 1) USE THE info to extract information about the move and change the reward accordingly
                
                # penalizes the passiveness of the player; rewards movement of boxes more
                if not info["action.moved_player"]:
                    reward = -0.5                
                elif info["action.moved_box"]:
                    reward = 0.2
#                 elif ....
                
                game_state_after_step = process_observation(environment=env, obs=observation)

                # IMAGE STUFF
                image = env.render(mode='rgb_array')
                viewer.render(image)

#                 # PRINT INFO
                logging.info(f'Population\'s steps info: {(ACTION_LOOKUP[action], reward, done, info)}')

                # POPULATE THE Episode reward +=
                # if the game didn't end on this step
                if not done:
                    ep_reward += reward
                    current_timestep += 1
                    
                # if the game ended
                else:
#                     current_timestep = 0
#                     current_episode += 1
                    print(f"I BEAT THE STUPID GAME!!! Happend on step {current_timestep}")
                    break
    
                    # OR BREAK

            # add the accumulated rewards for this episode into a list (episodes_rewards)   
            episodes_rewards.append(ep_reward)

        # choose the best performance on an episode for the genome
        genome.fitness = max(episodes_rewards)

#         print("All episodes finished. Closing window.")
        viewer.window.close()  # Close the Pyglet window explicitly
        


# Run until a solution is found. The number indicates the max number of generations to be produced
winner = p.run(eval_genomes, 50)


# Display the winning genome.
print('\nBest genome:\n{!s}'.format(winner))

# SAVE THE WINNER GENOME
with open("winner.pkl", "wb") as f:
    pickle.dump(winner, f)

# Show output of the most fit genome against training data.
print('\nOutput:')
winner_net = neat.nn.FeedForwardNetwork.create(winner, config)

# Save the winner
with open(file_name, 'wb') as f:
    pickle.dump(winner, f)
# Out:
# C:\Users\Mitko\.conda\envs\neat_test3\lib\site-packages\gym\utils\passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# C:\Users\Mitko\.conda\envs\neat_test3\lib\site-packages\gym\utils\passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# C:\Users\Mitko\.conda\envs\neat_test3\lib\site-packages\gym\utils\passive_env_checker.py:199: UserWarning: WARN: The result returned by `env.reset()` should be `(obs, info)` by default, , where `obs` is a observation and `info` is a dictionary containing additional information.
#   logger.warn(
#  ****** Running generation 123 ******
#
#
#  ****** Running generation 123 ******
# C:\Users\Mitko\.conda\envs\neat_test3\lib\site-packages\gym\utils\passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# C:\Users\Mitko\.conda\envs\neat_test3\lib\site-packages\gym\utils\passive_env_checker.py:289: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# Population's average fitness: -10.19429 stdev: 6.57282
# Best fitness: -3.70000 - size: (18, 300) - species 234 - id 40820
# Population's average fitness: -10.19429 stdev: 6.57282
# Best fitness: -3.70000 - size: (18, 300) - species 234 - id 40820
# Average adjusted fitness: 0.601
# Average adjusted fitness: 0.601
# Mean genetic distance 3.185, standard deviation 0.344
# Mean genetic distance 3.185, standard deviation 0.344
# Population of 428 members in 49 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    161   36    11     -4.0    0.621     5
#    181   28     8     -4.0    0.344    14
#    182   27    13     -4.0    0.728     5
#    184   26     8     -4.0    0.615    11
#    185   26    12     -3.7    0.704    13
#    188   24    10     -4.0    0.600     9
#    191   22     8     -4.0    0.706    12
#    192   20    11     -3.7    0.638     6
#    193   20     8     -4.0    0.429    14
#    196   19     9     -4.0    0.485    11
#    197   16    11     -4.0    0.641     4
#    198   16     8     -4.0    0.696     9
#    199   16     9     -4.0    0.566    13
#    200   15     5     -4.0    0.603    12
#    201   14     8     -4.0    0.427    12
#    202   14     9     -4.0    0.529    12
#    203   14     7     -4.0    0.366    13
#    204   14     7     -4.0    0.694    10
#    205   14    11     -4.0    0.623     4
#    206   13    10     -4.0    0.805     2
#    207   13    10     -4.0    0.658    12
#    208   13    11     -4.0    0.805     6
#    209   13     9     -3.7    0.515    10
#    210   12     9     -4.0    0.589    10
#    211   11     6     -4.4    0.949     3
#    212   10    10     -4.0    0.612     9
#    213   10    12     -4.0    0.667     8
#    214   10     8     -4.0    0.452     9
#    215   10     8     -4.0    0.471     8
#    216   10    12     -4.0    0.622     9
#    217   10     9     -4.0    0.525     1
#    218   10    10     -4.0    0.666     5
#    219    8     2    -18.8    0.055     0
#    220    7    12     -4.0    0.724     5
#    221    7    12     -4.0    0.708     5
#    222    5    11     -4.0    0.871     1
#    223    4     7     -4.0    0.279     1
#    224    2     8     -4.0    0.455     0
#    225    2     9     -4.0    0.738     1
#    226    2     3     -4.8    0.447     0
#    227    1     2     -4.0    0.660     0
#    228    1     8     -4.0    0.709     0
#    229    0     6     -4.0    0.642     0
#    230    0     6     -4.0    0.465     0
#    231    0     8     -4.4    0.589     0
#    232    0     5     -4.0    0.515     0
#    233    0    13     -4.0    0.954     0
#    234    0     9     -3.7    0.521     0
#    235    0    10     -4.0    0.761     0
# Total extinctions: 0
# Generation time: 808.633 sec
# Population of 428 members in 49 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    161   36    11     -4.0    0.621     5
#    181   28     8     -4.0    0.344    14
#    182   27    13     -4.0    0.728     5
#    184   26     8     -4.0    0.615    11
#    185   26    12     -3.7    0.704    13
#    188   24    10     -4.0    0.600     9
#    191   22     8     -4.0    0.706    12
#    192   20    11     -3.7    0.638     6
#    193   20     8     -4.0    0.429    14
#    196   19     9     -4.0    0.485    11
#    197   16    11     -4.0    0.641     4
#    198   16     8     -4.0    0.696     9
#    199   16     9     -4.0    0.566    13
#    200   15     5     -4.0    0.603    12
#    201   14     8     -4.0    0.427    12
#    202   14     9     -4.0    0.529    12
#    203   14     7     -4.0    0.366    13
#    204   14     7     -4.0    0.694    10
#    205   14    11     -4.0    0.623     4
#    206   13    10     -4.0    0.805     2
#    207   13    10     -4.0    0.658    12
#    208   13    11     -4.0    0.805     6
#    209   13     9     -3.7    0.515    10
#    210   12     9     -4.0    0.589    10
#    211   11     6     -4.4    0.949     3
#    212   10    10     -4.0    0.612     9
#    213   10    12     -4.0    0.667     8
#    214   10     8     -4.0    0.452     9
#    215   10     8     -4.0    0.471     8
#    216   10    12     -4.0    0.622     9
#    217   10     9     -4.0    0.525     1
#    218   10    10     -4.0    0.666     5
#    219    8     2    -18.8    0.055     0
#    220    7    12     -4.0    0.724     5
#    221    7    12     -4.0    0.708     5
#    222    5    11     -4.0    0.871     1
#    223    4     7     -4.0    0.279     1
#    224    2     8     -4.0    0.455     0
#    225    2     9     -4.0    0.738     1
#    226    2     3     -4.8    0.447     0
#    227    1     2     -4.0    0.660     0
#    228    1     8     -4.0    0.709     0
#    229    0     6     -4.0    0.642     0
#    230    0     6     -4.0    0.465     0
#    231    0     8     -4.4    0.589     0
#    232    0     5     -4.0    0.515     0
#    233    0    13     -4.0    0.954     0
#    234    0     9     -3.7    0.521     0
#    235    0    10     -4.0    0.761     0
# Total extinctions: 0
# Generation time: 808.633 sec
# Saving checkpoint to neat-checkpoint-v03-123
#
#  ****** Running generation 124 ******
#
#
#  ****** Running generation 124 ******
#
# Population's average fitness: -10.50187 stdev: 6.64733
# Best fitness: -3.40000 - size: (17, 285) - species 196 - id 33
# Population's average fitness: -10.50187 stdev: 6.64733
# Best fitness: -3.40000 - size: (17, 285) - species 196 - id 33
#
# Species 181 with 8 members is stagnated: removing it
#
# Species 181 with 8 members is stagnated: removing it
#
# Species 193 with 8 members is stagnated: removing it
#
# Species 193 with 8 members is stagnated: removing it
# Average adjusted fitness: 0.565
# Average adjusted fitness: 0.565
# Mean genetic distance 3.172, standard deviation 0.352
# Mean genetic distance 3.172, standard deviation 0.352
# Population of 507 members in 49 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    161   37    14     -3.7    0.775     6
#    182   28    13     -4.0    0.585     6
#    184   27    10     -3.8    0.508    12
#    185   27    14     -4.0    0.771    14
#    188   25    15     -4.0    0.947    10
#    191   23    12     -4.0    0.723    13
#    192   21    10     -4.0    0.390     7
#    196   20     9     -3.4    0.411    12
#    197   17    13     -3.8    0.606     5
#    198   17    12     -4.0    0.693    10
#    199   17    11     -4.0    0.600    14
#    200   16     7     -7.2    0.312    13
#    201   15     7     -4.8    0.255    13
#    202   15    11     -4.0    0.503    13
#    203   15    11     -4.0    0.660    14
#    204   15    11     -4.0    0.705    11
#    205   15    11     -4.0    0.515     5
#    206   14     9     -4.0    0.343     3
#    207   14    10     -4.0    0.475    13
#    208   14    11     -4.0    0.434     7
#    209   14    11     -4.0    0.546    11
#    210   13    11     -4.4    0.542    11
#    211   12     9     -4.0    0.541     4
#    212   11    10     -4.0    0.477    10
#    213   11    14     -4.0    0.789     9
#    214   11    10     -4.0    0.500    10
#    215   11    10     -4.0    0.491     9
#    216   11    10     -3.4    0.690     0
#    217   11    11     -4.0    0.514     2
#    218   11    12     -4.0    0.574     6
#    219    9     2    -18.8    0.060     1
#    220    8    12     -4.0    0.547     6
#    221    8    11     -4.0    0.636     6
#    222    6    10     -4.4    0.356     2
#    223    5    12     -4.0    0.698     2
#    224    3    11     -4.0    0.614     1
#    225    3    11     -4.0    0.554     2
#    226    3     8     -4.4    0.578     1
#    227    2    12     -4.0    0.964     1
#    228    2    10     -4.4    0.467     1
#    229    1     9     -4.0    0.493     1
#    230    1    10     -4.4    0.683     1
#    231    1    10     -4.0    0.515     0
#    232    1     7     -4.4    0.370     1
#    233    1     9     -4.0    0.734     1
#    234    1    11     -4.1    0.561     1
#    235    1    14     -4.0    0.867     1
#    236    0     8       --       --     0
#    237    0     1       --       --     0
# Total extinctions: 0
# Generation time: 724.618 sec (766.626 average)
# Population of 507 members in 49 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    161   37    14     -3.7    0.775     6
#    182   28    13     -4.0    0.585     6
#    184   27    10     -3.8    0.508    12
#    185   27    14     -4.0    0.771    14
#    188   25    15     -4.0    0.947    10
#    191   23    12     -4.0    0.723    13
#    192   21    10     -4.0    0.390     7
#    196   20     9     -3.4    0.411    12
#    197   17    13     -3.8    0.606     5
#    198   17    12     -4.0    0.693    10
#    199   17    11     -4.0    0.600    14
#    200   16     7     -7.2    0.312    13
#    201   15     7     -4.8    0.255    13
#    202   15    11     -4.0    0.503    13
#    203   15    11     -4.0    0.660    14
#    204   15    11     -4.0    0.705    11
#    205   15    11     -4.0    0.515     5
#    206   14     9     -4.0    0.343     3
#    207   14    10     -4.0    0.475    13
#    208   14    11     -4.0    0.434     7
#    209   14    11     -4.0    0.546    11
#    210   13    11     -4.4    0.542    11
#    211   12     9     -4.0    0.541     4
#    212   11    10     -4.0    0.477    10
#    213   11    14     -4.0    0.789     9
#    214   11    10     -4.0    0.500    10
#    215   11    10     -4.0    0.491     9
#    216   11    10     -3.4    0.690     0
#    217   11    11     -4.0    0.514     2
#    218   11    12     -4.0    0.574     6
#    219    9     2    -18.8    0.060     1
#    220    8    12     -4.0    0.547     6
#    221    8    11     -4.0    0.636     6
#    222    6    10     -4.4    0.356     2
#    223    5    12     -4.0    0.698     2
#    224    3    11     -4.0    0.614     1
#    225    3    11     -4.0    0.554     2
#    226    3     8     -4.4    0.578     1
#    227    2    12     -4.0    0.964     1
#    228    2    10     -4.4    0.467     1
#    229    1     9     -4.0    0.493     1
#    230    1    10     -4.4    0.683     1
#    231    1    10     -4.0    0.515     0
#    232    1     7     -4.4    0.370     1
#    233    1     9     -4.0    0.734     1
#    234    1    11     -4.1    0.561     1
#    235    1    14     -4.0    0.867     1
#    236    0     8       --       --     0
#    237    0     1       --       --     0
# Total extinctions: 0
# Generation time: 724.618 sec (766.626 average)
# Saving checkpoint to neat-checkpoint-v03-124
#  ****** Running generation 125 ******
#
#
#  ****** Running generation 125 ******
#
# Population's average fitness: -10.28304 stdev: 6.53457
# Best fitness: -3.40000 - size: (19, 306) - species 203 - id 576
# Population's average fitness: -10.28304 stdev: 6.53457
# Best fitness: -3.40000 - size: (19, 306) - species 203 - id 576
#
# Species 199 with 11 members is stagnated: removing it
#
# Species 199 with 11 members is stagnated: removing it
#
# Species 185 with 14 members is stagnated: removing it
#
# Species 185 with 14 members is stagnated: removing it
# Average adjusted fitness: 0.572
# Average adjusted fitness: 0.572
# Mean genetic distance 3.158, standard deviation 0.352
# Mean genetic distance 3.158, standard deviation 0.352
# Population of 489 members in 48 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    161   38    15     -4.0    0.790     7
#    182   29    12     -4.0    0.651     7
#    184   28    11     -4.0    0.612    13
#    188   26    14     -4.0    0.723    11
#    191   24    11     -4.0    0.626    14
#    192   22    11     -4.4    0.573     8
#    196   21     8     -4.4    0.376    13
#    197   18    12     -4.0    0.603     6
#    198   18    11     -4.0    0.546    11
#    200   17    10     -4.0    0.657    14
#    201   16    10     -4.4    0.735    14
#    202   16    12     -3.8    0.677     0
#    203   16    10     -3.4    0.568    15
#    204   16    10     -4.4    0.518    12
#    205   16    10     -4.0    0.451     6
#    206   15     8     -4.0    0.454     4
#    207   15    12     -4.0    0.735    14
#    208   15    13     -4.0    0.771     8
#    209   15    10     -4.1    0.536    12
#    210   14    10     -4.0    0.520    12
#    211   13     8     -4.4    0.409     5
#    212   12     8     -4.0    0.472    11
#    213   12    12     -4.0    0.510    10
#    214   12     8     -4.0    0.354    11
#    215   12    11     -4.0    0.607    10
#    216   12    11     -3.4    0.683     1
#    217   12    10     -4.0    0.470     3
#    218   12    10     -4.0    0.433     7
#    219   10     3    -17.6    0.108     2
#    220    9    10     -4.0    0.443     7
#    221    9     9     -4.0    0.543     7
#    222    7    11     -4.0    0.542     3
#    223    6    14     -4.0    0.694     3
#    224    4    10     -3.7    0.589     2
#    225    4    10     -4.0    0.556     3
#    226    4    11     -4.0    0.747     2
#    227    3    13     -4.0    0.673     2
#    228    3    11     -4.0    0.592     2
#    229    2     8     -4.0    0.483     2
#    230    2    11     -4.0    0.623     2
#    231    2     9     -4.0    0.478     1
#    232    2    10     -4.0    0.669     2
#    233    2     8     -4.0    0.574     2
#    234    2    12     -4.0    0.694     2
#    235    2    10     -4.0    0.368     2
#    236    1    12     -4.4    0.664     0
#    237    1     8     -6.8    0.795     0
#    238    0     1       --       --     0
# Total extinctions: 0
# Generation time: 850.922 sec (794.724 average)
# Population of 489 members in 48 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    161   38    15     -4.0    0.790     7
#    182   29    12     -4.0    0.651     7
#    184   28    11     -4.0    0.612    13
#    188   26    14     -4.0    0.723    11
#    191   24    11     -4.0    0.626    14
#    192   22    11     -4.4    0.573     8
#    196   21     8     -4.4    0.376    13
#    197   18    12     -4.0    0.603     6
#    198   18    11     -4.0    0.546    11
#    200   17    10     -4.0    0.657    14
#    201   16    10     -4.4    0.735    14
#    202   16    12     -3.8    0.677     0
#    203   16    10     -3.4    0.568    15
#    204   16    10     -4.4    0.518    12
#    205   16    10     -4.0    0.451     6
#    206   15     8     -4.0    0.454     4
#    207   15    12     -4.0    0.735    14
#    208   15    13     -4.0    0.771     8
#    209   15    10     -4.1    0.536    12
#    210   14    10     -4.0    0.520    12
#    211   13     8     -4.4    0.409     5
#    212   12     8     -4.0    0.472    11
#    213   12    12     -4.0    0.510    10
#    214   12     8     -4.0    0.354    11
#    215   12    11     -4.0    0.607    10
#    216   12    11     -3.4    0.683     1
#    217   12    10     -4.0    0.470     3
#    218   12    10     -4.0    0.433     7
#    219   10     3    -17.6    0.108     2
#    220    9    10     -4.0    0.443     7
#    221    9     9     -4.0    0.543     7
#    222    7    11     -4.0    0.542     3
#    223    6    14     -4.0    0.694     3
#    224    4    10     -3.7    0.589     2
#    225    4    10     -4.0    0.556     3
#    226    4    11     -4.0    0.747     2
#    227    3    13     -4.0    0.673     2
#    228    3    11     -4.0    0.592     2
#    229    2     8     -4.0    0.483     2
#    230    2    11     -4.0    0.623     2
#    231    2     9     -4.0    0.478     1
#    232    2    10     -4.0    0.669     2
#    233    2     8     -4.0    0.574     2
#    234    2    12     -4.0    0.694     2
#    235    2    10     -4.0    0.368     2
#    236    1    12     -4.4    0.664     0
#    237    1     8     -6.8    0.795     0
#    238    0     1       --       --     0
# Total extinctions: 0
# Generation time: 850.923 sec (794.725 average)
# Saving checkpoint to neat-checkpoint-v03-125
#
#  ****** Running generation 126 ******
#
#
#  ****** Running generation 126 ******
#
# Population's average fitness: -9.63415 stdev: 6.50379
# Best fitness: -3.40000 - size: (23, 329) - species 235 - id 731
# Population's average fitness: -9.63415 stdev: 6.50379
# Best fitness: -3.40000 - size: (23, 329) - species 235 - id 731
#
# Species 207 with 12 members is stagnated: removing it
#
# Species 207 with 12 members is stagnated: removing it
#
# Species 201 with 10 members is stagnated: removing it
#
# Species 201 with 10 members is stagnated: removing it
#
# Species 200 with 10 members is stagnated: removing it
#
# Species 200 with 10 members is stagnated: removing it
#
# Species 191 with 11 members is stagnated: removing it
#
# Species 191 with 11 members is stagnated: removing it
#
# Species 203 with 10 members is stagnated: removing it
#
# Species 203 with 10 members is stagnated: removing it
# Average adjusted fitness: 0.635
# Average adjusted fitness: 0.635
# Mean genetic distance 3.129, standard deviation 0.363
# Mean genetic distance 3.129, standard deviation 0.363
# Population of 512 members in 46 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    161   39    14     -4.0    0.568     8
#    182   30    13     -3.7    0.669     8
#    184   29    11     -4.0    0.583    14
#    188   27    13     -4.0    0.567    12
#    192   23    10     -4.0    0.378     9
#    196   22     7     -4.0    0.332    14
#    197   19    12     -4.0    0.621     7
#    198   19    11     -4.0    0.568    12
#    202   17    10     -4.0    0.679     1
#    204   17    12     -4.0    0.620    13
#    205   17    14     -4.0    0.831     7
#    206   16    10     -4.4    0.558     5
#    208   16    13     -4.0    0.606     9
#    209   16    13     -3.7    0.734    13
#    210   15    10     -4.0    0.436    13
#    211   14    12     -4.0    0.720     6
#    212   13    10     -4.0    0.515    12
#    213   13    14     -4.2    0.656    11
#    214   13    12     -4.0    0.747    12
#    215   13    13     -4.0    0.687    11
#    216   13    15     -4.0    0.881     2
#    217   13    12     -4.0    0.692     4
#    218   13    10     -4.0    0.471     8
#    219   11     2    -19.2    0.048     3
#    220   10    12     -4.4    0.680     8
#    221   10    11     -4.0    0.641     8
#    222    8    13     -4.0    0.653     4
#    223    7    16     -3.7    0.818     0
#    224    5    13     -4.0    0.751     3
#    225    5    12     -4.0    0.548     4
#    226    5    13     -4.0    0.676     3
#    227    4    15     -3.8    0.859     0
#    228    4     9     -3.7    0.429     0
#    229    3    11     -4.0    0.620     3
#    230    3    11     -4.0    0.484     3
#    231    3    14     -4.0    0.945     2
#    232    3    12     -4.0    0.705     3
#    233    3    14     -4.0    0.938     3
#    234    3    14     -4.0    0.691     3
#    235    3    13     -3.4    0.734     0
#    236    2    14     -4.0    0.808     0
#    237    2     6     -4.0    0.261     0
#    238    1    10     -5.0    0.904     0
#    239    0     4       --       --     0
#    240    0     1       --       --     0
#    241    0     1       --       --     0
# Total extinctions: 0
# Generation time: 808.909 sec (798.270 average)
# Population of 512 members in 46 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    161   39    14     -4.0    0.568     8
#    182   30    13     -3.7    0.669     8
#    184   29    11     -4.0    0.583    14
#    188   27    13     -4.0    0.567    12
#    192   23    10     -4.0    0.378     9
#    196   22     7     -4.0    0.332    14
#    197   19    12     -4.0    0.621     7
#    198   19    11     -4.0    0.568    12
#    202   17    10     -4.0    0.679     1
#    204   17    12     -4.0    0.620    13
#    205   17    14     -4.0    0.831     7
#    206   16    10     -4.4    0.558     5
#    208   16    13     -4.0    0.606     9
#    209   16    13     -3.7    0.734    13
#    210   15    10     -4.0    0.436    13
#    211   14    12     -4.0    0.720     6
#    212   13    10     -4.0    0.515    12
#    213   13    14     -4.2    0.656    11
#    214   13    12     -4.0    0.747    12
#    215   13    13     -4.0    0.687    11
#    216   13    15     -4.0    0.881     2
#    217   13    12     -4.0    0.692     4
#    218   13    10     -4.0    0.471     8
#    219   11     2    -19.2    0.048     3
#    220   10    12     -4.4    0.680     8
#    221   10    11     -4.0    0.641     8
#    222    8    13     -4.0    0.653     4
#    223    7    16     -3.7    0.818     0
#    224    5    13     -4.0    0.751     3
#    225    5    12     -4.0    0.548     4
#    226    5    13     -4.0    0.676     3
#    227    4    15     -3.8    0.859     0
#    228    4     9     -3.7    0.429     0
#    229    3    11     -4.0    0.620     3
#    230    3    11     -4.0    0.484     3
#    231    3    14     -4.0    0.945     2
#    232    3    12     -4.0    0.705     3
#    233    3    14     -4.0    0.938     3
#    234    3    14     -4.0    0.691     3
#    235    3    13     -3.4    0.734     0
#    236    2    14     -4.0    0.808     0
#    237    2     6     -4.0    0.261     0
#    238    1    10     -5.0    0.904     0
#    239    0     4       --       --     0
#    240    0     1       --       --     0
#    241    0     1       --       --     0
# Total extinctions: 0
# Generation time: 808.909 sec (798.271 average)
# Saving checkpoint to neat-checkpoint-v03-126
#  ****** Running generation 127 ******
#
#
#  ****** Running generation 127 ******
#
# Population's average fitness: -10.25234 stdev: 6.64654
# Best fitness: -3.70000 - size: (19, 307) - species 214 - id 1408
# Population's average fitness: -10.25234 stdev: 6.64654
# Best fitness: -3.70000 - size: (19, 307) - species 214 - id 1408
#
# Species 196 with 7 members is stagnated: removing it
#
# Species 196 with 7 members is stagnated: removing it
#
# Species 184 with 11 members is stagnated: removing it
#
# Species 184 with 11 members is stagnated: removing it
# Average adjusted fitness: 0.595
# Average adjusted fitness: 0.595
# Mean genetic distance 3.135, standard deviation 0.365
# Mean genetic distance 3.135, standard deviation 0.365
# Population of 499 members in 46 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    161   40    12     -4.0    0.488     9
#    182   31    13     -4.0    0.942     9
#    188   28    14     -4.0    0.681    13
#    192   24    11     -4.4    0.583    10
#    197   20    11     -4.0    0.491     8
#    198   20    10     -4.4    0.558    13
#    202   18     9     -4.0    0.475     2
#    204   18    13     -4.0    0.684    14
#    205   18    15     -3.7    0.764     8
#    206   17    11     -4.0    0.551     6
#    208   17    11     -3.8    0.517    10
#    209   17    12     -4.0    0.536    14
#    210   16    12     -4.0    0.693    14
#    211   15    11     -4.0    0.587     7
#    212   14     9     -4.0    0.437    13
#    213   14    13     -4.0    0.711    12
#    214   14     8     -3.7    0.462     0
#    215   14    12     -4.0    0.613    12
#    216   14    19     -4.0    0.829     3
#    217   14    10     -4.4    0.416     5
#    218   14     9     -4.0    0.507     9
#    219   12     2    -18.8    0.074     4
#    220   11    11     -4.0    0.606     9
#    221   11    13     -4.0    0.795     9
#    222    9    11     -4.0    0.492     5
#    223    8    15     -4.0    0.798     1
#    224    6    12     -4.0    0.547     4
#    225    6    11     -4.0    0.487     5
#    226    6    14     -4.0    0.735     4
#    227    5     4     -4.0    0.613     1
#    228    5     4     -4.0    0.487     1
#    229    4    10     -4.0    0.477     4
#    230    4    12     -4.0    0.636     4
#    231    4    13     -4.4    0.638     3
#    232    4    10     -4.0    0.390     4
#    233    4    13     -4.0    0.601     4
#    234    4    12     -4.0    0.555     4
#    235    4    12     -4.0    0.571     1
#    236    3    15     -4.0    0.766     1
#    237    3    12     -4.0    0.922     1
#    238    2     9     -4.0    0.463     0
#    239    1     9     -4.0    0.742     0
#    240    1    10    -14.8    0.319     0
#    241    1    12     -4.8    0.933     0
#    242    0     6       --       --     0
#    243    0     2       --       --     0
# Total extinctions: 0
# Generation time: 877.625 sec (814.141 average)
# Population of 499 members in 46 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    161   40    12     -4.0    0.488     9
#    182   31    13     -4.0    0.942     9
#    188   28    14     -4.0    0.681    13
#    192   24    11     -4.4    0.583    10
#    197   20    11     -4.0    0.491     8
#    198   20    10     -4.4    0.558    13
#    202   18     9     -4.0    0.475     2
#    204   18    13     -4.0    0.684    14
#    205   18    15     -3.7    0.764     8
#    206   17    11     -4.0    0.551     6
#    208   17    11     -3.8    0.517    10
#    209   17    12     -4.0    0.536    14
#    210   16    12     -4.0    0.693    14
#    211   15    11     -4.0    0.587     7
#    212   14     9     -4.0    0.437    13
#    213   14    13     -4.0    0.711    12
#    214   14     8     -3.7    0.462     0
#    215   14    12     -4.0    0.613    12
#    216   14    19     -4.0    0.829     3
#    217   14    10     -4.4    0.416     5
#    218   14     9     -4.0    0.507     9
#    219   12     2    -18.8    0.074     4
#    220   11    11     -4.0    0.606     9
#    221   11    13     -4.0    0.795     9
#    222    9    11     -4.0    0.492     5
#    223    8    15     -4.0    0.798     1
#    224    6    12     -4.0    0.547     4
#    225    6    11     -4.0    0.487     5
#    226    6    14     -4.0    0.735     4
#    227    5     4     -4.0    0.613     1
#    228    5     4     -4.0    0.487     1
#    229    4    10     -4.0    0.477     4
#    230    4    12     -4.0    0.636     4
#    231    4    13     -4.4    0.638     3
#    232    4    10     -4.0    0.390     4
#    233    4    13     -4.0    0.601     4
#    234    4    12     -4.0    0.555     4
#    235    4    12     -4.0    0.571     1
#    236    3    15     -4.0    0.766     1
#    237    3    12     -4.0    0.922     1
#    238    2     9     -4.0    0.463     0
#    239    1     9     -4.0    0.742     0
#    240    1    10    -14.8    0.319     0
#    241    1    12     -4.8    0.933     0
#    242    0     6       --       --     0
#    243    0     2       --       --     0
# Total extinctions: 0
# Generation time: 877.625 sec (814.142 average)
# Saving checkpoint to neat-checkpoint-v03-127
#
#  ****** Running generation 128 ******
#
#
#  ****** Running generation 128 ******
#
# Population's average fitness: -10.16393 stdev: 6.62148
# Best fitness: -3.40000 - size: (13, 302) - species 223 - id 1969
# Population's average fitness: -10.16393 stdev: 6.62148
# Best fitness: -3.40000 - size: (13, 302) - species 223 - id 1969
#
# Species 204 with 13 members is stagnated: removing it
#
# Species 204 with 13 members is stagnated: removing it
#
# Species 210 with 12 members is stagnated: removing it
#
# Species 210 with 12 members is stagnated: removing it
#
# Species 209 with 12 members is stagnated: removing it
#
# Species 209 with 12 members is stagnated: removing it
# Average adjusted fitness: 0.597
# Average adjusted fitness: 0.597
# Mean genetic distance 3.145, standard deviation 0.357
# Mean genetic distance 3.145, standard deviation 0.357
# Population of 485 members in 44 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    161   41    10     -4.0    0.422    10
#    182   32    11     -4.0    0.430    10
#    188   29    13     -4.0    0.656    14
#    192   25    12     -4.0    0.601    11
#    197   21    12     -3.8    0.649     9
#    198   21    11     -4.0    0.525    14
#    202   19    10     -4.0    0.576     3
#    205   19    12     -4.0    0.440     9
#    206   18    10     -4.0    0.550     7
#    208   18    13     -4.0    0.777    11
#    211   16    12     -4.0    0.588     8
#    212   15    11     -4.0    0.658    14
#    213   15    10     -4.0    0.558    13
#    214   15     7     -4.4    0.501     1
#    215   15    11     -4.0    0.547    13
#    216   15    16     -4.0    0.720     4
#    217   15    11     -4.0    0.627     6
#    218   15    10     -3.7    0.602    10
#    219   13     2    -18.8    0.060     5
#    220   12    10     -4.0    0.462    10
#    221   12    12     -4.0    0.530    10
#    222   10    13     -4.0    0.775     6
#    223    9    13     -3.4    0.591     0
#    224    7    13     -4.0    0.674     5
#    225    7    12     -4.0    0.567     6
#    226    7    16     -4.0    0.756     5
#    227    6     9     -4.4    0.723     2
#    228    6     7     -4.0    0.492     2
#    229    5    11     -4.0    0.661     5
#    230    5    11     -4.0    0.594     5
#    231    5    14     -4.0    0.756     4
#    232    5     9     -4.4    0.496     5
#    233    5    12     -4.4    0.605     5
#    234    5    11     -4.0    0.478     5
#    235    5    13     -4.0    0.728     2
#    236    4    14     -3.9    0.726     0
#    237    4    13     -4.0    0.636     2
#    238    3     8     -4.4    0.447     1
#    239    2    10     -4.0    0.513     1
#    240    2    11     -4.0    0.628     0
#    241    2    14     -3.8    0.776     0
#    242    1    12     -4.0    0.691     0
#    243    1    11     -4.8    0.867     0
#    244    0     2       --       --     0
# Total extinctions: 0
# Generation time: 823.865 sec (815.762 average)
# Population of 485 members in 44 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    161   41    10     -4.0    0.422    10
#    182   32    11     -4.0    0.430    10
#    188   29    13     -4.0    0.656    14
#    192   25    12     -4.0    0.601    11
#    197   21    12     -3.8    0.649     9
#    198   21    11     -4.0    0.525    14
#    202   19    10     -4.0    0.576     3
#    205   19    12     -4.0    0.440     9
#    206   18    10     -4.0    0.550     7
#    208   18    13     -4.0    0.777    11
#    211   16    12     -4.0    0.588     8
#    212   15    11     -4.0    0.658    14
#    213   15    10     -4.0    0.558    13
#    214   15     7     -4.4    0.501     1
#    215   15    11     -4.0    0.547    13
#    216   15    16     -4.0    0.720     4
#    217   15    11     -4.0    0.627     6
#    218   15    10     -3.7    0.602    10
#    219   13     2    -18.8    0.060     5
#    220   12    10     -4.0    0.462    10
#    221   12    12     -4.0    0.530    10
#    222   10    13     -4.0    0.775     6
#    223    9    13     -3.4    0.591     0
#    224    7    13     -4.0    0.674     5
#    225    7    12     -4.0    0.567     6
#    226    7    16     -4.0    0.756     5
#    227    6     9     -4.4    0.723     2
#    228    6     7     -4.0    0.492     2
#    229    5    11     -4.0    0.661     5
#    230    5    11     -4.0    0.594     5
#    231    5    14     -4.0    0.756     4
#    232    5     9     -4.4    0.496     5
#    233    5    12     -4.4    0.605     5
#    234    5    11     -4.0    0.478     5
#    235    5    13     -4.0    0.728     2
#    236    4    14     -3.9    0.726     0
#    237    4    13     -4.0    0.636     2
#    238    3     8     -4.4    0.447     1
#    239    2    10     -4.0    0.513     1
#    240    2    11     -4.0    0.628     0
#    241    2    14     -3.8    0.776     0
#    242    1    12     -4.0    0.691     0
#    243    1    11     -4.8    0.867     0
#    244    0     2       --       --     0
# Total extinctions: 0
# Generation time: 823.865 sec (815.762 average)
# Saving checkpoint to neat-checkpoint-v03-128
#  ****** Running generation 129 ******
#
#
#  ****** Running generation 129 ******
#
# Population's average fitness: -10.22969 stdev: 6.61712
# Best fitness: -3.40000 - size: (20, 298) - species 233 - id 2079
# Population's average fitness: -10.22969 stdev: 6.61712
# Best fitness: -3.40000 - size: (20, 298) - species 233 - id 2079
#
# Species 198 with 11 members is stagnated: removing it
#
# Species 198 with 11 members is stagnated: removing it
#
# Species 212 with 11 members is stagnated: removing it
#
# Species 212 with 11 members is stagnated: removing it
#
# Species 188 with 13 members is stagnated: removing it
#
# Species 188 with 13 members is stagnated: removing it
# Average adjusted fitness: 0.571
# Average adjusted fitness: 0.571
# Mean genetic distance 3.138, standard deviation 0.351
# Mean genetic distance 3.138, standard deviation 0.351
# Population of 507 members in 42 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    161   42     9     -4.0    0.383    11
#    182   33    11     -4.0    0.714    11
#    192   26    14     -4.0    0.679    12
#    197   22    12     -4.4    0.470    10
#    202   20    12     -4.0    0.563     4
#    205   20    14     -4.0    0.590    10
#    206   19    12     -4.0    0.595     8
#    208   19    12     -4.0    0.413    12
#    211   17    14     -4.0    0.690     9
#    213   16    14     -4.0    0.782    14
#    214   16     6     -4.0    0.410     2
#    215   16    14     -3.8    0.689     0
#    216   16    17     -4.0    0.768     5
#    217   16     9     -4.4    0.350     7
#    218   16     9     -4.1    0.387    11
#    219   14     2    -18.4    0.084     6
#    220   13     9     -4.0    0.358    11
#    221   13    14     -4.0    0.587    11
#    222   11    13     -4.4    0.532     7
#    223   10    13     -4.0    0.530     1
#    224    8    15     -4.0    0.740     6
#    225    8    10     -4.0    0.333     7
#    226    8    14     -4.0    0.508     6
#    227    7    15     -3.7    0.850     0
#    228    7    12     -4.0    0.705     3
#    229    6    10     -4.4    0.428     6
#    230    6    14     -4.0    0.687     6
#    231    6    17     -4.0    0.851     5
#    232    6    13     -4.0    0.722     6
#    233    6    14     -3.4    0.597     0
#    234    6    15     -4.0    0.762     6
#    235    6    12     -4.0    0.451     3
#    236    5    14     -3.8    0.559     0
#    237    5    13     -4.4    0.574     3
#    238    4    10     -4.0    0.556     2
#    239    3    12     -4.0    0.469     2
#    240    3    10     -4.0    0.465     1
#    241    3    16     -4.0    0.697     1
#    242    2    16     -4.0    0.732     1
#    243    2    15     -4.0    0.568     0
#    244    1     7     -4.4    0.587     0
#    245    0     3       --       --     0
# Total extinctions: 0
# Generation time: 800.904 sec (813.639 average)
# Population of 507 members in 42 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    161   42     9     -4.0    0.383    11
#    182   33    11     -4.0    0.714    11
#    192   26    14     -4.0    0.679    12
#    197   22    12     -4.4    0.470    10
#    202   20    12     -4.0    0.563     4
#    205   20    14     -4.0    0.590    10
#    206   19    12     -4.0    0.595     8
#    208   19    12     -4.0    0.413    12
#    211   17    14     -4.0    0.690     9
#    213   16    14     -4.0    0.782    14
#    214   16     6     -4.0    0.410     2
#    215   16    14     -3.8    0.689     0
#    216   16    17     -4.0    0.768     5
#    217   16     9     -4.4    0.350     7
#    218   16     9     -4.1    0.387    11
#    219   14     2    -18.4    0.084     6
#    220   13     9     -4.0    0.358    11
#    221   13    14     -4.0    0.587    11
#    222   11    13     -4.4    0.532     7
#    223   10    13     -4.0    0.530     1
#    224    8    15     -4.0    0.740     6
#    225    8    10     -4.0    0.333     7
#    226    8    14     -4.0    0.508     6
#    227    7    15     -3.7    0.850     0
#    228    7    12     -4.0    0.705     3
#    229    6    10     -4.4    0.428     6
#    230    6    14     -4.0    0.687     6
#    231    6    17     -4.0    0.851     5
#    232    6    13     -4.0    0.722     6
#    233    6    14     -3.4    0.597     0
#    234    6    15     -4.0    0.762     6
#    235    6    12     -4.0    0.451     3
#    236    5    14     -3.8    0.559     0
#    237    5    13     -4.4    0.574     3
#    238    4    10     -4.0    0.556     2
#    239    3    12     -4.0    0.469     2
#    240    3    10     -4.0    0.465     1
#    241    3    16     -4.0    0.697     1
#    242    2    16     -4.0    0.732     1
#    243    2    15     -4.0    0.568     0
#    244    1     7     -4.4    0.587     0
#    245    0     3       --       --     0
# Total extinctions: 0
# Generation time: 800.905 sec (813.640 average)
# Saving checkpoint to neat-checkpoint-v03-129
#
#  ****** Running generation 130 ******
#
#
#  ****** Running generation 130 ******
#
# Population's average fitness: -10.33156 stdev: 6.60531
# Best fitness: -3.40000 - size: (15, 295) - species 226 - id 2643
# Population's average fitness: -10.33156 stdev: 6.60531
# Best fitness: -3.40000 - size: (15, 295) - species 226 - id 2643
#
# Species 213 with 14 members is stagnated: removing it
#
# Species 213 with 14 members is stagnated: removing it
# Average adjusted fitness: 0.565
# Average adjusted fitness: 0.565
# Mean genetic distance 3.140, standard deviation 0.355
# Mean genetic distance 3.140, standard deviation 0.355
# Population of 494 members in 42 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    161   43    13     -3.7    0.789    12
#    182   34    12     -4.0    0.744    12
#    192   27    12     -3.7    0.492    13
#    197   23    10     -4.4    0.413    11
#    202   21    11     -4.0    0.471     5
#    205   21    12     -4.4    0.450    11
#    206   20    13     -4.0    0.576     9
#    208   20    10     -4.0    0.390    13
#    211   18    13     -4.0    0.642    10
#    214   17    11     -4.0    0.627     3
#    215   17    15     -3.4    0.728     0
#    216   17    15     -4.0    0.645     6
#    217   17    10     -4.0    0.537     8
#    218   17     8     -4.0    0.310    12
#    219   15     2    -18.8    0.072     7
#    220   14    10     -4.0    0.446    12
#    221   14    12     -4.0    0.487    12
#    222   12    14     -4.0    0.624     8
#    223   11    14     -4.0    0.648     2
#    224    9    14     -4.0    0.647     7
#    225    9     9     -4.0    0.419     8
#    226    9    12     -3.4    0.466     0
#    227    8    16     -4.0    0.715     1
#    228    8    12     -3.4    0.516     0
#    229    7    11     -3.7    0.590     0
#    230    7    15     -4.0    0.676     7
#    231    7    16     -3.7    0.704     0
#    232    7    12     -4.0    0.601     7
#    233    7    11     -4.0    0.388     1
#    234    7    14     -4.0    0.663     7
#    235    7    13     -4.0    0.674     4
#    236    6    16     -3.4    0.818     0
#    237    6     9     -4.4    0.253     4
#    238    5    12     -4.0    0.669     3
#    239    4    10     -4.0    0.365     3
#    240    4     8     -4.4    0.435     2
#    241    4    15     -3.7    0.690     0
#    242    3    15     -4.0    0.685     2
#    243    3    15     -4.0    0.763     1
#    244    2    11     -4.4    0.680     1
#    245    1     8     -4.8    0.657     0
#    246    0     3       --       --     0
# Total extinctions: 0
# Generation time: 839.023 sec (816.812 average)
# Population of 494 members in 42 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    161   43    13     -3.7    0.789    12
#    182   34    12     -4.0    0.744    12
#    192   27    12     -3.7    0.492    13
#    197   23    10     -4.4    0.413    11
#    202   21    11     -4.0    0.471     5
#    205   21    12     -4.4    0.450    11
#    206   20    13     -4.0    0.576     9
#    208   20    10     -4.0    0.390    13
#    211   18    13     -4.0    0.642    10
#    214   17    11     -4.0    0.627     3
#    215   17    15     -3.4    0.728     0
#    216   17    15     -4.0    0.645     6
#    217   17    10     -4.0    0.537     8
#    218   17     8     -4.0    0.310    12
#    219   15     2    -18.8    0.072     7
#    220   14    10     -4.0    0.446    12
#    221   14    12     -4.0    0.487    12
#    222   12    14     -4.0    0.624     8
#    223   11    14     -4.0    0.648     2
#    224    9    14     -4.0    0.647     7
#    225    9     9     -4.0    0.419     8
#    226    9    12     -3.4    0.466     0
#    227    8    16     -4.0    0.715     1
#    228    8    12     -3.4    0.516     0
#    229    7    11     -3.7    0.590     0
#    230    7    15     -4.0    0.676     7
#    231    7    16     -3.7    0.704     0
#    232    7    12     -4.0    0.601     7
#    233    7    11     -4.0    0.388     1
#    234    7    14     -4.0    0.663     7
#    235    7    13     -4.0    0.674     4
#    236    6    16     -3.4    0.818     0
#    237    6     9     -4.4    0.253     4
#    238    5    12     -4.0    0.669     3
#    239    4    10     -4.0    0.365     3
#    240    4     8     -4.4    0.435     2
#    241    4    15     -3.7    0.690     0
#    242    3    15     -4.0    0.685     2
#    243    3    15     -4.0    0.763     1
#    244    2    11     -4.4    0.680     1
#    245    1     8     -4.8    0.657     0
#    246    0     3       --       --     0
# Total extinctions: 0
# Generation time: 839.023 sec (816.813 average)
# Saving checkpoint to neat-checkpoint-v03-130
#  ****** Running generation 131 ******
#
#
#  ****** Running generation 131 ******
#
# Population's average fitness: -10.15587 stdev: 6.59942
# Best fitness: -3.40000 - size: (19, 292) - species 233 - id 2869
# Population's average fitness: -10.15587 stdev: 6.59942
# Best fitness: -3.40000 - size: (19, 292) - species 233 - id 2869
# Average adjusted fitness: 0.570
# Average adjusted fitness: 0.570
# Mean genetic distance 3.127, standard deviation 0.351
# Mean genetic distance 3.127, standard deviation 0.351
# Population of 496 members in 43 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    161   44    10     -4.0    0.350    13
#    182   35    11     -4.0    0.491    13
#    192   28    11     -4.0    0.570    14
#    197   24     9     -4.0    0.439    12
#    202   22    13     -4.0    0.686     6
#    205   22    13     -4.0    0.707    12
#    206   21    15     -4.0    0.767    10
#    208   21    11     -4.0    0.611    14
#    211   19    14     -4.0    0.711    11
#    214   18    12     -4.0    0.618     4
#    215   18    13     -3.4    0.498     1
#    216   18    16     -4.0    0.838     7
#    217   18     8     -4.0    0.328     9
#    218   18     9     -4.0    0.451    13
#    219   16     3    -18.0    0.108     8
#    220   15    11     -3.8    0.604    13
#    221   15    11     -4.0    0.459    13
#    222   13    13     -4.0    0.549     9
#    223   12    13     -4.0    0.600     3
#    224   10    12     -4.0    0.447     8
#    225   10    10     -4.0    0.509     9
#    226   10    13     -3.8    0.700     1
#    227    9    14     -4.0    0.613     2
#    228    9    11     -3.7    0.519     1
#    229    8    12     -4.0    0.620     1
#    230    8    16     -4.0    0.800     8
#    231    8    14     -4.0    0.593     1
#    232    8    12     -4.0    0.639     8
#    233    8    12     -3.4    0.624     0
#    234    8    15     -4.0    0.674     8
#    235    8    12     -3.8    0.506     5
#    236    7    15     -3.8    0.741     1
#    237    7    10     -4.0    0.477     5
#    238    6    11     -4.0    0.546     4
#    239    5    11     -4.0    0.552     4
#    240    5     9     -4.0    0.492     3
#    241    5    14     -4.0    0.715     1
#    242    4    16     -4.0    0.746     3
#    243    4    14     -3.4    0.616     0
#    244    3    12     -4.2    0.644     0
#    245    2     7     -4.8    0.294     1
#    246    1     7     -4.8    0.500     0
#    247    0     1       --       --     0
# Total extinctions: 0
# Generation time: 815.188 sec (816.632 average)
# Population of 496 members in 43 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    161   44    10     -4.0    0.350    13
#    182   35    11     -4.0    0.491    13
#    192   28    11     -4.0    0.570    14
#    197   24     9     -4.0    0.439    12
#    202   22    13     -4.0    0.686     6
#    205   22    13     -4.0    0.707    12
#    206   21    15     -4.0    0.767    10
#    208   21    11     -4.0    0.611    14
#    211   19    14     -4.0    0.711    11
#    214   18    12     -4.0    0.618     4
#    215   18    13     -3.4    0.498     1
#    216   18    16     -4.0    0.838     7
#    217   18     8     -4.0    0.328     9
#    218   18     9     -4.0    0.451    13
#    219   16     3    -18.0    0.108     8
#    220   15    11     -3.8    0.604    13
#    221   15    11     -4.0    0.459    13
#    222   13    13     -4.0    0.549     9
#    223   12    13     -4.0    0.600     3
#    224   10    12     -4.0    0.447     8
#    225   10    10     -4.0    0.509     9
#    226   10    13     -3.8    0.700     1
#    227    9    14     -4.0    0.613     2
#    228    9    11     -3.7    0.519     1
#    229    8    12     -4.0    0.620     1
#    230    8    16     -4.0    0.800     8
#    231    8    14     -4.0    0.593     1
#    232    8    12     -4.0    0.639     8
#    233    8    12     -3.4    0.624     0
#    234    8    15     -4.0    0.674     8
#    235    8    12     -3.8    0.506     5
#    236    7    15     -3.8    0.741     1
#    237    7    10     -4.0    0.477     5
#    238    6    11     -4.0    0.546     4
#    239    5    11     -4.0    0.552     4
#    240    5     9     -4.0    0.492     3
#    241    5    14     -4.0    0.715     1
#    242    4    16     -4.0    0.746     3
#    243    4    14     -3.4    0.616     0
#    244    3    12     -4.2    0.644     0
#    245    2     7     -4.8    0.294     1
#    246    1     7     -4.8    0.500     0
#    247    0     1       --       --     0
# Total extinctions: 0
# Generation time: 815.189 sec (816.632 average)
# Saving checkpoint to neat-checkpoint-v03-131
#
#  ****** Running generation 132 ******
#
#
#  ****** Running generation 132 ******
#
# Population's average fitness: -9.78710 stdev: 6.62253
# Best fitness: -3.40000 - size: (18, 299) - species 243 - id 2957
# Population's average fitness: -9.78710 stdev: 6.62253
# Best fitness: -3.40000 - size: (18, 299) - species 243 - id 2957
#
# Species 208 with 11 members is stagnated: removing it
#
# Species 208 with 11 members is stagnated: removing it
#
# Species 192 with 11 members is stagnated: removing it
#
# Species 192 with 11 members is stagnated: removing it
# Average adjusted fitness: 0.622
# Average adjusted fitness: 0.622
# Mean genetic distance 3.140, standard deviation 0.348
# Mean genetic distance 3.140, standard deviation 0.348
# Population of 491 members in 42 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    161   45    13     -4.0    0.790    14
#    182   36    13     -4.0    0.602    14
#    197   25    12     -4.0    0.728    13
#    202   23    14     -4.0    0.691     7
#    205   23     9     -4.0    0.699    13
#    206   22    14     -4.0    0.665    11
#    211   20    13     -3.7    0.688    12
#    214   19    13     -4.0    0.618     5
#    215   19    15     -4.0    0.818     2
#    216   19    15     -4.0    0.703     8
#    217   19    11     -4.0    0.698    10
#    218   19    10     -4.0    0.488    14
#    219   17     2    -18.0    0.096     9
#    220   16    10     -4.0    0.494    14
#    221   16    12     -4.0    0.708    14
#    222   14    12     -4.0    0.568    10
#    223   13    14     -4.0    0.674     4
#    224   11    10     -4.0    0.383     9
#    225   11     8     -4.0    0.275    10
#    226   11    12     -4.4    0.583     2
#    227   10    13     -4.0    0.710     3
#    228   10    13     -4.0    0.751     2
#    229    9    14     -4.0    0.772     2
#    230    9    12     -4.0    0.438     9
#    231    9    13     -3.9    0.633     2
#    232    9     8     -4.0    0.389     9
#    233    9    11     -4.0    0.600     1
# ...
# 	DefaultConnectionGene(key=(-19, 1), weight=0.29013341871832476, enabled=False)
# 	DefaultConnectionGene(key=(-19, 2), weight=-0.22167757904851407, enabled=True)
# 	DefaultConnectionGene(key=(-19, 3), weight=-1.0515266516364965, enabled=True)
# 	DefaultConnectionGene(key=(-19, 4), weight=-2.702617963273738, enabled=True)
# 	DefaultConnectionGene(key=(-19, 5), weight=-1.4020864881770088, enabled=True)
# 	DefaultConnectionGene(key=(-19, 6), weight=-2.460294615769605, enabled=True)
# 	DefaultConnectionGene(key=(-19, 7), weight=0.8855894973066226, enabled=True)
# 	DefaultConnectionGene(key=(-19, 8), weight=-4.451137832213698, enabled=False)
# 	DefaultConnectionGene(key=(-19, 11782), weight=-5.550754615639766, enabled=True)
# 	DefaultConnectionGene(key=(-18, 0), weight=-2.17523450446713, enabled=True)
# 	DefaultConnectionGene(key=(-18, 1), weight=1.1264839410773049, enabled=False)
# 	DefaultConnectionGene(key=(-18, 2), weight=-1.442878723953494, enabled=True)
# 	DefaultConnectionGene(key=(-18, 3), weight=-2.1933502154810154, enabled=True)
# 	DefaultConnectionGene(key=(-18, 4), weight=0.6483231263771541, enabled=True)
# 	DefaultConnectionGene(key=(-18, 5), weight=1.4822384746039412, enabled=True)
# 	DefaultConnectionGene(key=(-18, 6), weight=-2.476341780409635, enabled=True)
# 	DefaultConnectionGene(key=(-18, 7), weight=-3.000945901422748, enabled=False)
# 	DefaultConnectionGene(key=(-18, 8), weight=-1.3919159252724058, enabled=True)
# 	DefaultConnectionGene(key=(-18, 14278), weight=5.562425570446774, enabled=True)
# 	DefaultConnectionGene(key=(-18, 14643), weight=-0.8256516407416856, enabled=True)
# 	DefaultConnectionGene(key=(-18, 16951), weight=2.767007610961552, enabled=True)
# 	DefaultConnectionGene(key=(-17, 0), weight=-0.06215662972121225, enabled=True)
# 	DefaultConnectionGene(key=(-17, 2), weight=-1.8954845140341199, enabled=True)
# 	DefaultConnectionGene(key=(-17, 3), weight=-2.575557450876193, enabled=False)
# 	DefaultConnectionGene(key=(-17, 4), weight=0.8603176305588416, enabled=True)
# 	DefaultConnectionGene(key=(-17, 5), weight=0.7013216079828211, enabled=True)
# 	DefaultConnectionGene(key=(-17, 7), weight=-1.2492402218353922, enabled=True)
# 	DefaultConnectionGene(key=(-17, 8), weight=0.3231899535624557, enabled=True)
# 	DefaultConnectionGene(key=(-17, 13536), weight=-1.549205102673247, enabled=False)
# 	DefaultConnectionGene(key=(-16, 0), weight=3.2774184165981635, enabled=True)
# 	DefaultConnectionGene(key=(-16, 1), weight=0.5199155865123414, enabled=False)
# 	DefaultConnectionGene(key=(-16, 2), weight=0.9151881879098593, enabled=False)
# 	DefaultConnectionGene(key=(-16, 3), weight=-1.148991548758491, enabled=False)
# 	DefaultConnectionGene(key=(-16, 4), weight=3.760941881761687, enabled=True)
# 	DefaultConnectionGene(key=(-16, 5), weight=2.380719335612295, enabled=True)
# 	DefaultConnectionGene(key=(-16, 7), weight=2.959200710382072, enabled=False)
# 	DefaultConnectionGene(key=(-16, 8), weight=2.979536911252522, enabled=False)
# 	DefaultConnectionGene(key=(-15, 0), weight=-3.0568389253950907, enabled=True)
# 	DefaultConnectionGene(key=(-15, 1), weight=-2.5745767032357483, enabled=True)
# 	DefaultConnectionGene(key=(-15, 2), weight=0.24403960632066415, enabled=True)
# 	DefaultConnectionGene(key=(-15, 3), weight=-2.337932888613182, enabled=False)
# 	DefaultConnectionGene(key=(-15, 4), weight=0.375467397410745, enabled=False)
# 	DefaultConnectionGene(key=(-15, 5), weight=-1.259353273254802, enabled=False)
# 	DefaultConnectionGene(key=(-15, 6), weight=-1.663648876399327, enabled=True)
# 	DefaultConnectionGene(key=(-15, 7), weight=1.7227401808112637, enabled=False)
# 	DefaultConnectionGene(key=(-15, 8), weight=-0.3703596357466968, enabled=True)
# 	DefaultConnectionGene(key=(-15, 20698), weight=0.6520202728538923, enabled=True)
# 	DefaultConnectionGene(key=(-14, 0), weight=0.27908403456872055, enabled=True)
# 	DefaultConnectionGene(key=(-14, 1), weight=-1.6623714993187195, enabled=True)
# 	DefaultConnectionGene(key=(-14, 2), weight=1.5392669460376591, enabled=True)
# 	DefaultConnectionGene(key=(-14, 3), weight=-1.014526032892102, enabled=True)
# 	DefaultConnectionGene(key=(-14, 4), weight=-0.46393730004437755, enabled=True)
# 	DefaultConnectionGene(key=(-14, 5), weight=-1.9627597184655432, enabled=True)
# 	DefaultConnectionGene(key=(-14, 6), weight=-1.1043466150306325, enabled=False)
# 	DefaultConnectionGene(key=(-14, 7), weight=0.22278524975540565, enabled=False)
# 	DefaultConnectionGene(key=(-14, 8), weight=2.712041421029349, enabled=False)
# 	DefaultConnectionGene(key=(-13, 0), weight=-2.0210105901277733, enabled=True)
# 	DefaultConnectionGene(key=(-13, 1), weight=-3.298008409712629, enabled=True)
# 	DefaultConnectionGene(key=(-13, 2), weight=-0.9139256364315144, enabled=True)
# 	DefaultConnectionGene(key=(-13, 3), weight=3.61251208295978, enabled=True)
# 	DefaultConnectionGene(key=(-13, 4), weight=1.9321984515254451, enabled=True)
# 	DefaultConnectionGene(key=(-13, 5), weight=-1.5854372334942501, enabled=False)
# 	DefaultConnectionGene(key=(-13, 6), weight=0.10688199745116855, enabled=True)
# 	DefaultConnectionGene(key=(-13, 7), weight=-1.8423231187195783, enabled=True)
# 	DefaultConnectionGene(key=(-13, 8), weight=0.22136707934150435, enabled=True)
# 	DefaultConnectionGene(key=(-13, 14747), weight=-1.0039493325718079, enabled=True)
# 	DefaultConnectionGene(key=(-12, 1), weight=-0.38815257594384095, enabled=True)
# 	DefaultConnectionGene(key=(-12, 2), weight=1.3902837208558765, enabled=False)
# 	DefaultConnectionGene(key=(-12, 3), weight=-1.2487370243235052, enabled=False)
# 	DefaultConnectionGene(key=(-12, 4), weight=-1.2045720862611045, enabled=False)
# 	DefaultConnectionGene(key=(-12, 5), weight=-0.05940684326744383, enabled=False)
# 	DefaultConnectionGene(key=(-12, 6), weight=1.4588690463747884, enabled=True)
# 	DefaultConnectionGene(key=(-12, 7), weight=0.8070219364041689, enabled=True)
# 	DefaultConnectionGene(key=(-11, 0), weight=0.6206075201813838, enabled=False)
# 	DefaultConnectionGene(key=(-11, 1), weight=-3.2646797952479263, enabled=True)
# 	DefaultConnectionGene(key=(-11, 2), weight=0.3242049004465108, enabled=True)
# 	DefaultConnectionGene(key=(-11, 3), weight=0.07198167210205897, enabled=True)
# 	DefaultConnectionGene(key=(-11, 4), weight=0.12886955266208494, enabled=False)
# 	DefaultConnectionGene(key=(-11, 5), weight=0.24200364025350798, enabled=True)
# 	DefaultConnectionGene(key=(-11, 6), weight=-0.6888586393572567, enabled=True)
# 	DefaultConnectionGene(key=(-11, 7), weight=-0.49008983942166784, enabled=True)
# 	DefaultConnectionGene(key=(-11, 8), weight=2.6444645764195336, enabled=True)
# 	DefaultConnectionGene(key=(-10, 1), weight=-1.2048750539035722, enabled=False)
# 	DefaultConnectionGene(key=(-10, 2), weight=0.30414251788862934, enabled=True)
# 	DefaultConnectionGene(key=(-10, 3), weight=0.49805511096881405, enabled=False)
# 	DefaultConnectionGene(key=(-10, 4), weight=0.0677486581442832, enabled=False)
# 	DefaultConnectionGene(key=(-10, 5), weight=-0.21298693832419727, enabled=True)
# 	DefaultConnectionGene(key=(-10, 6), weight=-1.6338567773281651, enabled=True)
# 	DefaultConnectionGene(key=(-10, 7), weight=0.8121090798797385, enabled=True)
# 	DefaultConnectionGene(key=(-10, 8), weight=0.5962817594866281, enabled=True)
# 	DefaultConnectionGene(key=(-9, 0), weight=1.139050845107207, enabled=True)
# 	DefaultConnectionGene(key=(-9, 1), weight=2.2175292862096927, enabled=False)
# 	DefaultConnectionGene(key=(-9, 2), weight=3.6986378616089644, enabled=True)
# 	DefaultConnectionGene(key=(-9, 3), weight=2.025949201945891, enabled=True)
# 	DefaultConnectionGene(key=(-9, 4), weight=0.9521769723392224, enabled=True)
# 	DefaultConnectionGene(key=(-9, 5), weight=-2.0709081680695873, enabled=True)
# 	DefaultConnectionGene(key=(-9, 6), weight=0.01579940557215741, enabled=False)
# 	DefaultConnectionGene(key=(-9, 7), weight=-1.5748463367660164, enabled=True)
# 	DefaultConnectionGene(key=(-9, 8), weight=-0.4312349785620839, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=-2.387210519219676, enabled=True)
# 	DefaultConnectionGene(key=(-8, 1), weight=2.2982768023751934, enabled=True)
# 	DefaultConnectionGene(key=(-8, 2), weight=-1.5492532265485837, enabled=True)
# 	DefaultConnectionGene(key=(-8, 3), weight=-1.6458599691504543, enabled=True)
# 	DefaultConnectionGene(key=(-8, 4), weight=-0.2289015546762731, enabled=True)
# 	DefaultConnectionGene(key=(-8, 5), weight=-1.2292518725060055, enabled=True)
# 	DefaultConnectionGene(key=(-8, 6), weight=-0.09088162145869835, enabled=True)
# 	DefaultConnectionGene(key=(-8, 7), weight=0.6480577690057674, enabled=False)
# 	DefaultConnectionGene(key=(-8, 8), weight=-1.3321533286441882, enabled=False)
# 	DefaultConnectionGene(key=(-7, 0), weight=-0.4339205231030061, enabled=True)
# 	DefaultConnectionGene(key=(-7, 1), weight=-0.718718074770458, enabled=True)
# 	DefaultConnectionGene(key=(-7, 2), weight=-0.39774925670062644, enabled=False)
# 	DefaultConnectionGene(key=(-7, 3), weight=0.7613211407495063, enabled=True)
# 	DefaultConnectionGene(key=(-7, 4), weight=-0.83457868860565, enabled=True)
# 	DefaultConnectionGene(key=(-7, 5), weight=-5.40329613278917, enabled=True)
# 	DefaultConnectionGene(key=(-7, 6), weight=0.3628861356619085, enabled=False)
# 	DefaultConnectionGene(key=(-7, 7), weight=0.1578642654151835, enabled=False)
# 	DefaultConnectionGene(key=(-7, 8), weight=-0.5736011216439295, enabled=True)
# 	DefaultConnectionGene(key=(-6, 0), weight=-2.3450508059190383, enabled=True)
# 	DefaultConnectionGene(key=(-6, 1), weight=0.2886349181868009, enabled=True)
# 	DefaultConnectionGene(key=(-6, 2), weight=3.6658134328807686, enabled=False)
# 	DefaultConnectionGene(key=(-6, 3), weight=-0.29405095191452923, enabled=True)
# 	DefaultConnectionGene(key=(-6, 4), weight=0.3774437023615199, enabled=True)
# 	DefaultConnectionGene(key=(-6, 5), weight=1.2231343750879304, enabled=True)
# 	DefaultConnectionGene(key=(-6, 6), weight=2.0898792293296564, enabled=False)
# 	DefaultConnectionGene(key=(-6, 7), weight=2.900511667898458, enabled=True)
# 	DefaultConnectionGene(key=(-6, 8), weight=-0.613347285337223, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=2.1988637736768917, enabled=False)
# 	DefaultConnectionGene(key=(-5, 1), weight=-1.4418578162813285, enabled=True)
# 	DefaultConnectionGene(key=(-5, 2), weight=-3.571197617363333, enabled=False)
# 	DefaultConnectionGene(key=(-5, 3), weight=0.7911072431609527, enabled=True)
# 	DefaultConnectionGene(key=(-5, 4), weight=0.13869828325394154, enabled=False)
# 	DefaultConnectionGene(key=(-5, 5), weight=2.432469125298144, enabled=True)
# 	DefaultConnectionGene(key=(-5, 6), weight=4.480875515223653, enabled=False)
# 	DefaultConnectionGene(key=(-5, 7), weight=3.454468959109693, enabled=True)
# 	DefaultConnectionGene(key=(-5, 8), weight=-0.17846346317767864, enabled=True)
# 	DefaultConnectionGene(key=(-5, 21638), weight=-0.5835349282329689, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=0.37602330114110866, enabled=False)
# 	DefaultConnectionGene(key=(-4, 1), weight=-0.3559589077084222, enabled=True)
# 	DefaultConnectionGene(key=(-4, 2), weight=0.805107148593155, enabled=True)
# 	DefaultConnectionGene(key=(-4, 3), weight=-1.499539301198964, enabled=False)
# 	DefaultConnectionGene(key=(-4, 4), weight=-0.5006062089033849, enabled=False)
# 	DefaultConnectionGene(key=(-4, 5), weight=0.8225989408380572, enabled=True)
# 	DefaultConnectionGene(key=(-4, 6), weight=-0.42787310469055284, enabled=True)
# 	DefaultConnectionGene(key=(-4, 7), weight=-2.719454069845076, enabled=True)
# 	DefaultConnectionGene(key=(-4, 8), weight=-0.9681972392758618, enabled=False)
# 	DefaultConnectionGene(key=(-3, 0), weight=0.9184541706121118, enabled=True)
# 	DefaultConnectionGene(key=(-3, 1), weight=1.693734202542152, enabled=True)
# 	DefaultConnectionGene(key=(-3, 2), weight=1.1012732038048854, enabled=True)
# 	DefaultConnectionGene(key=(-3, 3), weight=5.492225913486323, enabled=False)
# 	DefaultConnectionGene(key=(-3, 4), weight=-0.43840769738411245, enabled=True)
# 	DefaultConnectionGene(key=(-3, 5), weight=1.1220298925942616, enabled=True)
# 	DefaultConnectionGene(key=(-3, 6), weight=-0.489883935459545, enabled=False)
# 	DefaultConnectionGene(key=(-3, 7), weight=2.9662343852110897, enabled=False)
# 	DefaultConnectionGene(key=(-3, 8), weight=-0.5672548082256539, enabled=False)
# 	DefaultConnectionGene(key=(-3, 15681), weight=0.3445197127832236, enabled=False)
# 	DefaultConnectionGene(key=(-2, 0), weight=-2.205916634090386, enabled=False)
# 	DefaultConnectionGene(key=(-2, 1), weight=0.9914953563855695, enabled=False)
# 	DefaultConnectionGene(key=(-2, 2), weight=-0.38410643997134913, enabled=False)
# 	DefaultConnectionGene(key=(-2, 3), weight=-0.14753514391000988, enabled=False)
# 	DefaultConnectionGene(key=(-2, 4), weight=1.0727135886221566, enabled=True)
# 	DefaultConnectionGene(key=(-2, 5), weight=0.28934813557509315, enabled=True)
# 	DefaultConnectionGene(key=(-2, 6), weight=1.5938559888201662, enabled=False)
# 	DefaultConnectionGene(key=(-2, 7), weight=4.154625736828099, enabled=False)
# 	DefaultConnectionGene(key=(-2, 8), weight=0.7740022347744681, enabled=False)
# 	DefaultConnectionGene(key=(-1, 0), weight=-1.250992257063611, enabled=True)
# 	DefaultConnectionGene(key=(-1, 1), weight=3.7979897283385533, enabled=False)
# 	DefaultConnectionGene(key=(-1, 2), weight=1.5051152098694875, enabled=True)
# 	DefaultConnectionGene(key=(-1, 3), weight=0.6296931343434131, enabled=False)
# 	DefaultConnectionGene(key=(-1, 4), weight=-1.8062726424928197, enabled=False)
# 	DefaultConnectionGene(key=(-1, 5), weight=-1.8549191044512952, enabled=False)
# 	DefaultConnectionGene(key=(-1, 6), weight=-0.09589648547613527, enabled=False)
# 	DefaultConnectionGene(key=(-1, 7), weight=2.5194818988114944, enabled=False)
# 	DefaultConnectionGene(key=(-1, 8), weight=-0.2802210971168353, enabled=True)
# 	DefaultConnectionGene(key=(-1, 17200), weight=-0.38636475128537057, enabled=True)
# 	DefaultConnectionGene(key=(0, 0), weight=-2.144391182263309, enabled=True)
# 	DefaultConnectionGene(key=(2, 2), weight=1.7825739670747844, enabled=False)
# 	DefaultConnectionGene(key=(3, 3), weight=1.6833700464481944, enabled=True)
# 	DefaultConnectionGene(key=(3, 19538), weight=0.48761138005745264, enabled=True)
# 	DefaultConnectionGene(key=(4, 4), weight=-1.3078668762725556, enabled=True)
# 	DefaultConnectionGene(key=(5, 5), weight=1.7428995059254622, enabled=True)
# 	DefaultConnectionGene(key=(6, 6), weight=2.713668449633272, enabled=False)
# 	DefaultConnectionGene(key=(7, 7), weight=0.5499174712952104, enabled=True)
# 	DefaultConnectionGene(key=(8, 8), weight=0.9591084425557956, enabled=True)
# 	DefaultConnectionGene(key=(9401, 5), weight=-0.44707463954152205, enabled=True)
# 	DefaultConnectionGene(key=(11782, 0), weight=-1.8189462876516005, enabled=True)
# 	DefaultConnectionGene(key=(11782, 18663), weight=3.1263300482970284, enabled=True)
# 	DefaultConnectionGene(key=(13536, 3), weight=0.8021648703458195, enabled=True)
# 	DefaultConnectionGene(key=(14278, 6), weight=1.124419341676443, enabled=True)
# 	DefaultConnectionGene(key=(14278, 20698), weight=-2.61061289435715, enabled=True)
# 	DefaultConnectionGene(key=(14643, 5), weight=0.849600711612415, enabled=False)
# 	DefaultConnectionGene(key=(14747, 5), weight=1.1517857806322178, enabled=True)
# 	DefaultConnectionGene(key=(15681, 7), weight=-0.6414281426864833, enabled=True)
# 	DefaultConnectionGene(key=(16951, 14278), weight=2.9255645985734224, enabled=True)
# 	DefaultConnectionGene(key=(16951, 17119), weight=-1.3792565969869275, enabled=True)
# 	DefaultConnectionGene(key=(17119, 8), weight=-2.178903803186135, enabled=False)
# 	DefaultConnectionGene(key=(17200, 3), weight=2.6476014094810694, enabled=True)
# 	DefaultConnectionGene(key=(17304, 7), weight=-0.10351728837140917, enabled=True)
# 	DefaultConnectionGene(key=(18162, 6), weight=-1.2137038625122116, enabled=True)
# 	DefaultConnectionGene(key=(18663, 0), weight=1.8388495370665217, enabled=True)
# 	DefaultConnectionGene(key=(19538, 3), weight=3.4396638316122514, enabled=True)
# 	DefaultConnectionGene(key=(20698, 7), weight=1.3669702223620357, enabled=False)
# 	DefaultConnectionGene(key=(21246, 3), weight=4.947255789977644, enabled=True)
# 	DefaultConnectionGene(key=(21638, 0), weight=-0.7252142735824495, enabled=True)
#
# Output:

# %%
visualize.plot_stats(stats, ylog=False, view=True)
visualize.plot_species(stats, view=True)

# %%
visualize.draw_net(config=config, genome=winner)

# %%
import neat

# Load configuration.
config_filename = 'config-feedforward_v01'
config = neat.Config(neat.DefaultGenome, 
                     neat.DefaultReproduction, 
                     neat.DefaultSpeciesSet, 
                     neat.DefaultStagnation, 
                     config_filename)

config.genome_config.add_node_mutation_prob = 0.03
config.genome_config.add_connection_mutation_prob = 0.05

# Print the parsed parameters to debug
print("Initial connection type:", config.genome_config.initial_connection)
print("Allowed connectivity options:", config.genome_config.allowed_connectivity)
print("Activation options:", config.genome_config.activation_options)

# %% [markdown]
# ### ChatGPT

# %%
import neat
import gym
import gym_sokoban
import pyglet
import numpy as np

import time
import logging
from neat.reporting import StdOutReporter

# Custom rendering setup if gym's rendering is not available
class Viewer:
    def __init__(self, width, height):
        self.window = pyglet.window.Window(width, height)
        self.image = None
        self.window.on_draw = self.on_draw

    def render(self, image):
        self.image = pyglet.image.ImageData(image.shape[1], image.shape[0], 'RGB', image.tobytes(), pitch=image.shape[1] * -3)
        self.window.dispatch_event('on_draw')

    def on_draw(self):
        if self.image:
            self.window.clear()
            self.image.blit(0, 0)

# Initialize logging
logging.basicConfig(filename='neat_log.txt', level=logging.INFO, format='%(message)s')

# Custom reporter class
class CustomReporter(StdOutReporter):
    def __init__(self, show_species_detail):
        super().__init__(show_species_detail)
        self.start_time = time.time()
    
    def end(self):
        runtime = time.time() - self.start_time
        logging.info(f'Total runtime: {runtime:.2f} seconds')

    def post_evaluate(self, config, population, species_set, best_genome):
        super().post_evaluate(config, population, species_set, best_genome)
        
        # Log population's average fitness
        total_fitness = sum(genome.fitness for genome in population.values())
        avg_fitness = total_fitness / len(population)
        logging.info(f'Population\'s average fitness: {avg_fitness}')
        
        # Log adjusted fitness score
        adjusted_fitness = []
        for species_id, species in species_set.species.items():
            for genome_id in species.members:
                genome = population[genome_id]
                adjusted_fitness.append(genome.fitness / len(species.members))
        avg_adjusted_fitness = sum(adjusted_fitness) / len(adjusted_fitness)
        logging.info(f'Population\'s average adjusted fitness: {avg_adjusted_fitness}')
        
        # Log best genome information
        logging.info(f'\nBest genome:\nKey: {best_genome.key}\nFitness: {best_genome.fitness}')
        logging.info(f'Nodes:')
        for node_key, node in best_genome.nodes.items():
            logging.info(f'\t{node_key} {node}')
        logging.info(f'Connections:')
        for conn_key, conn in best_genome.connections.items():
            logging.info(f'\t{conn_key} {conn}')
        logging.info(f'Timestamp: {time.strftime("%Y-%m-%d %H:%M:%S")}')


def process_observation(environment, obs):
    # Convert the observation to RGB frame or custom observation
    arr_walls, arr_goals, arr_boxes, arr_player = environment.render(mode='raw')

    # Initialize the combined array with walls (1s)
    combined = np.ones_like(arr_walls)
    
    # Set empty fields (0s)
    combined[arr_walls == 0] = 0
    
    # Set targets (3s)
    combined[arr_goals == 1] = 3
    
    # Set boxes (2s)
    combined[arr_boxes == 1] = 2
    
    # Set boxes on targets (4s)
    combined[(arr_boxes == 1) & (arr_goals == 1)] = 4
    
    # Set player position (5s)
    combined[arr_player == 1] = 5

    # Flatten the array
    flat_array = combined.flatten()
    
    return flat_array


def process_state(state):
    # Processes the initial state of env.reset()

    # Initialize the combined array with walls (0s)
    combined = np.ones_like(state[0])
    
    # Set empty fields (1s)
    combined[state[0] == 0] = 0

    # Set targets (3s)
    combined[state[1] == 1] = 3

    # Set boxes (2s)
    combined[state[2] == 1] = 2

    # Set boxes on targets (4s)
    combined[(state[2] == 1) & (state[1] == 1)] = 4

    # Set player position (5s)
    combined[state[3] == 1] = 5

    # Flatten the array
    flat_array = combined.flatten()
    
    return flat_array


# Start the game
env = gym.make('Sokoban-small-v1')
env.reset()

# Optional viewer setup
viewer = Viewer(160, 160)  # Adjust the size according to your environment
ACTION_LOOKUP = env.unwrapped.get_action_lookup()

# Define episode and timestep parameters
num_episodes = 1
timesteps_per_episode = 40

def map_action(action_prob):
    return np.argmax(action_prob)

def eval_genomes(genomes, config):
    global num_episodes, timesteps_per_episode

    # For each genome
    for genome_id, genome in genomes:
        # Generate the neural network based on the config provided
        net = neat.nn.FeedForwardNetwork.create(genome, config)
    
        # Define the initial fitness of the genome
        genome.fitness = 0.0
    
        # Define episodes rewards (list) idea is to keep the fitness scores of all episodes and take the max
        episodes_rewards = []
        
        # For each episode
        for episode in range(num_episodes):
            # Episode reward = 0  
            ep_reward = 0
            
            # Reset the game state to the initial phase
            initial_state = env.reset()

            # Map inputs suitable for the Neural Network (initial state of the game as flatten array, e.g. with length 49, created by the initial 7x7 grid)
            # Used as an input layer in the Neural Network
            initial_inputs = process_state(initial_state)
            
            game_state_after_step = initial_inputs
            
            # For each step
            for step in range(timesteps_per_episode):
                # Calculate probabilities for each output to be selected
                action_prob = net.activate(game_state_after_step)
                
                # Select the action, based on the output's probabilities of being selected
                action = map_action(action_prob)
                
                # Make the move in the game and output game state + info + reward
                observation, reward, done, info = env.step(action)
                
                game_state_after_step = process_observation(environment=env, obs=observation)

                # Image stuff
                image = env.render(mode='rgb_array')
                viewer.render(image)

                # Print info
                print(ACTION_LOOKUP[action], reward, done, info)

                # Populate the episode reward
                if not done:
                    ep_reward += reward
                else:
                    print(f"Game finished in {step+1} steps")
                    break
    
            # Add the accumulated rewards for this episode into a list (episodes_rewards)   
            episodes_rewards.append(ep_reward)

        # Choose the best performance on an episode for the genome
        genome.fitness = max(episodes_rewards)

        print("All episodes finished. Closing window.")
        viewer.window.close()  # Close the Pyglet window explicitly

# Load configuration.
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
                     'config-feedforward')

# Create the population, which is the top-level object for a NEAT run.
p = neat.Population(config)

# Add a stdout reporter to show progress in the terminal.
p.add_reporter(neat.StdOutReporter(True))
p.add_reporter(CustomReporter(True))
p.add_reporter(neat.StatisticsReporter())

# Run until a solution is found. The number indicates the max number of generations to be produced
winner = p.run(eval_genomes, 5)

# Display the winning genome.
print('\nBest genome:\n{!s}'.format(winner))

# Show output of the most fit genome against training data.
print('\nOutput:')
winner_net = neat.nn.FeedForwardNetwork.create(winner, config)

# Start the Pyglet event loop to keep the window open
pyglet.app.run()

# %% [markdown]
# ### BACKUP

# %%
# Start the game

env = gym.make('Sokoban-small-v1')
# generate the level in the initial stage (env.reset) 
env.reset()


# # OPTIONAL

# viewer = Viewer(160, 160)  # Adjust the size according to your environment

# ACTION_LOOKUP = env.unwrapped.get_action_lookup()

# Define episode and timestep parameters
num_episodes = 1
timesteps_per_episode = 40

current_episode = 0
current_timestep = 0

min_reward = -10


def eval_genomes(genomes, config)
# FOR EACH GENOME
    for genome_id, genome in genomes:
        
        env = gym.make()
    # net = neat.nn.FeedForwardNetwork.create(genome, config)
    # DEF INITIAL GENOME FITNESS = 0
    
    
    # EPISODES REWARDS = [] IDEA IS TO KEEP THE FITNESS SCORES OF ALL EPISODES AND THEN TAKE THE MAX
    
    # FOR EACH EPISODE
        # Episode reward = 0  
        # env.reset()
            
        # FOR EACH STEP
            # ACTION - GENERATED BY THE GENOME
            # RANDOM ACTION
            action = env.action_space.sample()
            
            # MAKE THE MOVE IN THE GAME
            # OUTPUT GAME STATE AFTER THE STEP WITH INFO + REWARD            
            observation, reward, done, info = env.step(action)
            
            
            # IMAGE STUFF
            image = env.render(mode='rgb_array')
            viewer.render(image)
            
            # PRINT INFO
            print(ACTION_LOOKUP[action], reward, done, info)

            # POPULATE THE Episode reward +=
            # if not done:
                # reward += MIN REWARD
                # current_timestep += 1

            # if done:
                # current_timestep = 0
                # current_episode += 1

                # OR BREAK

        # EPISODES REWARDS APPEND episode reward   
        
    
    # GENOME.FITNESS = max(EPISODE REWARDS)        
                

        

# # Load configuration.
# config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
#                      neat.DefaultSpeciesSet, neat.DefaultStagnation,
#                      'config-feedforward')

# # Create the population, which is the top-level object for a NEAT run.
# p = neat.Population(config)

# # Add a stdout reporter to show progress in the terminal.
# p.add_reporter(neat.StdOutReporter(False))

# # Run until a solution is found.
# winner = p.run(eval_genomes, 5)

# # Display the winning genome.
# print('\nBest genome:\n{!s}'.format(winner))

# # Show output of the most fit genome against training data.
# print('\nOutput:')
# winner_net = neat.nn.FeedForwardNetwork.create(winner, config)

# %% [markdown]
# ### Game logic

# %%
import gym
import gym_sokoban
import pyglet
from pyglet import clock
import numpy as np

## Custom rendering setup if gym's rendering is not available
class Viewer:
    def __init__(self, width, height):
        self.window = pyglet.window.Window(width, height)
        self.image = None
        self.window.on_draw = self.on_draw

    def render(self, image):
        self.image = pyglet.image.ImageData(image.shape[1], image.shape[0], 'RGB', image.tobytes(), pitch=image.shape[1] * -3)
        self.window.dispatch_event('on_draw')

    def on_draw(self):
        if self.image:
            self.window.clear()
            self.image.blit(0, 0)

env = gym.make('Sokoban-small-v1')
# generate the level in the initial stage (env.reset) 
env.reset()

print("Room Fixed")
print(env.room_fixed)
print(type(env.room_fixed))
print(env.room_fixed.shape)
print()
print(env.room_state)
print()
print(env.box_mapping)
print()


viewer = Viewer(160, 160)  # Adjust the size according to your environment

ACTION_LOOKUP = env.unwrapped.get_action_lookup()

# Define episode and timestep parameters
num_episodes = 2
timesteps_per_episode = 100

current_episode = 0
current_timestep = 0

def update_environment(dt):
    global current_episode, current_timestep, num_episodes, timesteps_per_episode

    if current_episode < num_episodes:
        if current_timestep < timesteps_per_episode:
            # RANDOM ACTION
            action = env.action_space.sample()
            observation, reward, done, info = env.step(action)
            
            
            
            image = env.render(mode='rgb_array')
            viewer.render(image)

            print(ACTION_LOOKUP[action], reward, done, info)

            if done:
                print(f"Episode finished after {current_timestep + 1} timesteps")
                current_timestep = 0
                current_episode += 1
                env.reset()
            else:
                current_timestep += 1
        else:
            current_episode += 1
            current_timestep = 0
            env.reset()
    else:
        print("All episodes finished. Closing window.")
        viewer.window.close()  # Close the Pyglet window explicitly

# Increase the frequency to match rendering needs (e.g., 60Hz)
clock.schedule_interval(update_environment, 1/60.0)

pyglet.app.run()
