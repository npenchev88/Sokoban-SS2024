# %%
import gym
import gym_sokoban
import pyglet
import time
from stable_baselines3 import PPO

# %%
## Custom rendering setup if gym's rendering is not available
class Viewer:
    def __init__(self, width, height):
        self.window = pyglet.window.Window(width, height)

    def render(self, image):
        self.window.clear()
        pyglet.image.ImageData(image.shape[1], image.shape[0], 'RGB', image.tobytes(), pitch=image.shape[1]*-3).blit(0, 0)
        self.window.flip()

# %%
env = gym.make('Sokoban-small-v1')
model = PPO('MlpPolicy', env, verbose=1)

# Train the model
model.learn(total_timesteps=100000)
# Save the model to a file
model.save("ppo_test")

# loaded_model = PPO.load("ppo_test")

env.reset()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# /home/npenchev/anaconda3/envs/sokoban_2/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/npenchev/.local/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# /home/npenchev/.local/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# /home/npenchev/.local/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'numpy.ndarray'>`
#   logger.warn(
# /home/npenchev/.local/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /home/npenchev/.local/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:225: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -19.6    |
# | time/              |          |
# |    fps             | 125      |
# |    iterations      | 1        |
# |    time_elapsed    | 16       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -19.5       |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 2           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016124057 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | -0.0351     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0568      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 0.282       |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Not enough free spots (#4) to place 1 player and 3 boxes.
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -19.4       |
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 3           |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013585389 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.207       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00321    |
# |    value_loss           | 0.36        |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -19.4      |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 4          |
# |    time_elapsed         | 104        |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01315744 |
# |    clip_fraction        | 0.0619     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.18      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.356      |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00409   |
# |    value_loss           | 0.564      |
# ----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | -18.5       |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 5           |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016276369 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.229       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00963    |
# |    value_loss           | 0.76        |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Not enough free spots (#4) to place 1 player and 3 boxes.
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | -18.7       |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 6           |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.016163897 |
# |    clip_fraction        | 0.0789      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00582    |
# |    value_loss           | 2.83        |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Not enough free spots (#3) to place 1 player and 3 boxes.
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Not enough free spots (#4) to place 1 player and 3 boxes.
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Not enough free spots (#3) to place 1 player and 3 boxes.
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | -18.7       |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 7           |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.014471728 |
# |    clip_fraction        | 0.0987      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.597       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00518    |
# |    value_loss           | 1.1         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 198        |
# |    ep_rew_mean          | -18.8      |
# | time/                   |            |
# |    fps                  | 72         |
# |    iterations           | 8          |
# |    time_elapsed         | 226        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01262379 |
# |    clip_fraction        | 0.0652     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.18      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.375      |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00435   |
# |    value_loss           | 1.14       |
# ----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 195         |
# |    ep_rew_mean          | -18.3       |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 9           |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.016503483 |
# |    clip_fraction        | 0.0932      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.218       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00705    |
# |    value_loss           | 1.3         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 195         |
# |    ep_rew_mean          | -18.3       |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 10          |
# |    time_elapsed         | 291         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012954753 |
# |    clip_fraction        | 0.0968      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.646       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00764    |
# |    value_loss           | 3.58        |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | -18         |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 11          |
# |    time_elapsed         | 322         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011767689 |
# |    clip_fraction        | 0.0664      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.645       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00456    |
# |    value_loss           | 1.37        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | -18         |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 12          |
# |    time_elapsed         | 354         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013873711 |
# |    clip_fraction        | 0.0806      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.545       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00532    |
# |    value_loss           | 2.71        |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Not enough free spots (#4) to place 1 player and 3 boxes.
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | -18         |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 13          |
# |    time_elapsed         | 385         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010134669 |
# |    clip_fraction        | 0.0446      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.886       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00198    |
# |    value_loss           | 1.45        |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | -18.2       |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 14          |
# |    time_elapsed         | 418         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.012919143 |
# |    clip_fraction        | 0.0894      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.821       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00622    |
# |    value_loss           | 1.51        |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 195         |
# |    ep_rew_mean          | -18.4       |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 15          |
# |    time_elapsed         | 450         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.014533818 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00595    |
# |    value_loss           | 1.54        |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 195         |
# |    ep_rew_mean          | -18.5       |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 16          |
# |    time_elapsed         | 483         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011068655 |
# |    clip_fraction        | 0.0855      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.626       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00619    |
# |    value_loss           | 1.56        |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Not enough free spots (#3) to place 1 player and 3 boxes.
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 195         |
# |    ep_rew_mean          | -18.5       |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 17          |
# |    time_elapsed         | 514         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011685277 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.07        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00674    |
# |    value_loss           | 1.6         |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 195         |
# |    ep_rew_mean          | -18.5       |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 18          |
# |    time_elapsed         | 546         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.013295088 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.98       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.442       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00668    |
# |    value_loss           | 1.7         |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Not enough free spots (#3) to place 1 player and 3 boxes.
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | -18.8       |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 19          |
# |    time_elapsed         | 578         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010332812 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.546       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00353    |
# |    value_loss           | 2.86        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | -18.9       |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 20          |
# |    time_elapsed         | 608         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009959217 |
# |    clip_fraction        | 0.0744      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.943       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00461    |
# |    value_loss           | 1.54        |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | -19.1       |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 21          |
# |    time_elapsed         | 640         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.013012756 |
# |    clip_fraction        | 0.0937      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.692       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00449    |
# |    value_loss           | 1.59        |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 198          |
# |    ep_rew_mean          | -19.1        |
# | time/                   |              |
# |    fps                  | 67           |
# |    iterations           | 22           |
# |    time_elapsed         | 670          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0142573025 |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.821        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00649     |
# |    value_loss           | 1.63         |
# ------------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 197        |
# |    ep_rew_mean          | -18.8      |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 23         |
# |    time_elapsed         | 701        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01296322 |
# |    clip_fraction        | 0.151      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.89      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.469      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0102    |
# |    value_loss           | 1.77       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | -18.8       |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 24          |
# |    time_elapsed         | 733         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006799898 |
# |    clip_fraction        | 0.0463      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.42        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0021     |
# |    value_loss           | 3.84        |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | -18.7       |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 25          |
# |    time_elapsed         | 766         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010972829 |
# |    clip_fraction        | 0.0399      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.411       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00108    |
# |    value_loss           | 1.63        |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 197          |
# |    ep_rew_mean          | -18.8        |
# | time/                   |              |
# |    fps                  | 66           |
# |    iterations           | 26           |
# |    time_elapsed         | 799          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0056707426 |
# |    clip_fraction        | 0.0535       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.79        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.723        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00198     |
# |    value_loss           | 1.59         |
# ------------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | -18.8       |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 27          |
# |    time_elapsed         | 836         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.010761749 |
# |    clip_fraction        | 0.095       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.526       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.006      |
# |    value_loss           | 1.65        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | -18.7       |
# | time/                   |             |
# |    fps                  | 65          |
# |    iterations           | 28          |
# |    time_elapsed         | 871         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.012443215 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.43        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00715    |
# |    value_loss           | 3.73        |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 198          |
# |    ep_rew_mean          | -18.8        |
# | time/                   |              |
# |    fps                  | 65           |
# |    iterations           | 29           |
# |    time_elapsed         | 905          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0056874664 |
# |    clip_fraction        | 0.0365       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.8         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.406        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 1.54         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | -18.7       |
# | time/                   |             |
# |    fps                  | 65          |
# |    iterations           | 30          |
# |    time_elapsed         | 938         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008891894 |
# |    clip_fraction        | 0.0675      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.379       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00351    |
# |    value_loss           | 1.6         |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 197          |
# |    ep_rew_mean          | -18.4        |
# | time/                   |              |
# |    fps                  | 65           |
# |    iterations           | 31           |
# |    time_elapsed         | 970          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0048451824 |
# |    clip_fraction        | 0.0335       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.993        |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000743    |
# |    value_loss           | 1.63         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 197          |
# |    ep_rew_mean          | -18.3        |
# | time/                   |              |
# |    fps                  | 65           |
# |    iterations           | 32           |
# |    time_elapsed         | 1002         |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0063316333 |
# |    clip_fraction        | 0.0732       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.71        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.794        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00347     |
# |    value_loss           | 3.73         |
# ------------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | -18.7       |
# | time/                   |             |
# |    fps                  | 65          |
# |    iterations           | 33          |
# |    time_elapsed         | 1033        |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.012586618 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.34        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 1.68        |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | -18.8       |
# | time/                   |             |
# |    fps                  | 65          |
# |    iterations           | 34          |
# |    time_elapsed         | 1068        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.009391047 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.303       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00655    |
# |    value_loss           | 1.6         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | -18.5       |
# | time/                   |             |
# |    fps                  | 65          |
# |    iterations           | 35          |
# |    time_elapsed         | 1099        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.008312689 |
# |    clip_fraction        | 0.0176      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.334       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.000394    |
# |    value_loss           | 1.68        |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 197          |
# |    ep_rew_mean          | -18.7        |
# | time/                   |              |
# |    fps                  | 65           |
# |    iterations           | 36           |
# |    time_elapsed         | 1133         |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0045435987 |
# |    clip_fraction        | 0.0424       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.41         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00213     |
# |    value_loss           | 2.82         |
# ------------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 197          |
# |    ep_rew_mean          | -18.8        |
# | time/                   |              |
# |    fps                  | 65           |
# |    iterations           | 37           |
# |    time_elapsed         | 1165         |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0059301425 |
# |    clip_fraction        | 0.0737       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00405     |
# |    value_loss           | 1.59         |
# ------------------------------------------
# [SOKOBAN] Runtime Error/Warning: Not enough free spots (#4) to place 1 player and 3 boxes.
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 197          |
# |    ep_rew_mean          | -18.8        |
# | time/                   |              |
# |    fps                  | 64           |
# |    iterations           | 38           |
# |    time_elapsed         | 1197         |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0073085222 |
# |    clip_fraction        | 0.0579       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.917        |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00317     |
# |    value_loss           | 1.77         |
# ------------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | -18.8       |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 39          |
# |    time_elapsed         | 1229        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.004361867 |
# |    clip_fraction        | 0.0478      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.998       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00291    |
# |    value_loss           | 1.59        |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Not enough free spots (#2) to place 1 player and 3 boxes.
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | -18.8       |
# | time/                   |             |
# |    fps                  | 65          |
# |    iterations           | 40          |
# |    time_elapsed         | 1259        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005264949 |
# |    clip_fraction        | 0.0881      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.515       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00459    |
# |    value_loss           | 1.66        |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -19.1        |
# | time/                   |              |
# |    fps                  | 63           |
# |    iterations           | 41           |
# |    time_elapsed         | 1323         |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0054362062 |
# |    clip_fraction        | 0.0544       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.641        |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00337     |
# |    value_loss           | 1.63         |
# ------------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 198          |
# |    ep_rew_mean          | -18.9        |
# | time/                   |              |
# |    fps                  | 63           |
# |    iterations           | 42           |
# |    time_elapsed         | 1356         |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0068604695 |
# |    clip_fraction        | 0.049        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.1          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0016      |
# |    value_loss           | 1.8          |
# ------------------------------------------
# [SOKOBAN] Runtime Error/Warning: Not enough free spots (#4) to place 1 player and 3 boxes.
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | -18.9       |
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 43          |
# |    time_elapsed         | 1390        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.004719831 |
# |    clip_fraction        | 0.0375      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.67        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0019     |
# |    value_loss           | 2.67        |
# -----------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Not enough free spots (#4) to place 1 player and 3 boxes.
# [SOKOBAN] Retry . . .
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 198          |
# |    ep_rew_mean          | -19          |
# | time/                   |              |
# |    fps                  | 63           |
# |    iterations           | 44           |
# |    time_elapsed         | 1424         |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0057138987 |
# |    clip_fraction        | 0.0629       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.44         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00281     |
# |    value_loss           | 1.63         |
# ------------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -19.2        |
# | time/                   |              |
# |    fps                  | 63           |
# |    iterations           | 45           |
# |    time_elapsed         | 1457         |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0031319957 |
# |    clip_fraction        | 0.0439       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.533        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00355     |
# |    value_loss           | 1.7          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -19.2        |
# | time/                   |              |
# |    fps                  | 63           |
# |    iterations           | 46           |
# |    time_elapsed         | 1491         |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0025036423 |
# |    clip_fraction        | 0.0389       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.929       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.65         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 1.68         |
# ------------------------------------------
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -19.2        |
# | time/                   |              |
# |    fps                  | 63           |
# |    iterations           | 47           |
# |    time_elapsed         | 1526         |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0037467885 |
# |    clip_fraction        | 0.0408       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.9         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 1.68         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -19.2        |
# | time/                   |              |
# |    fps                  | 63           |
# |    iterations           | 48           |
# |    time_elapsed         | 1560         |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0036778897 |
# |    clip_fraction        | 0.0365       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.834       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.642        |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00198     |
# |    value_loss           | 1.69         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -19.2        |
# | time/                   |              |
# |    fps                  | 62           |
# |    iterations           | 49           |
# |    time_elapsed         | 1595         |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0033493827 |
# |    clip_fraction        | 0.0511       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.704       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.997        |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00273     |
# |    value_loss           | 1.82         |
# ------------------------------------------
# array([[[176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0],
#         ...,
#         [176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0]],
#
#        [[176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0],
#         ...,
#         [176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0]],
#
#        [[176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0],
#         ...,
#         [176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0]],
#
#        ...,
#
#        [[176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0],
#         ...,
#         [176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0]],
#
#        [[176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0],
#         ...,
#         [176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0]],
#
#        [[176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0],
#         ...,
#         [176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0]]], dtype=uint8)

# %%
viewer = Viewer(160, 160)  # Adjust the size according to your environment

# %%
ACTION_LOOKUP = env.unwrapped.get_action_lookup()
# print("Created environment: {}".format('Sokoban-v2'))
#
for i_episode in range(1):#20
    # observation = env.reset()

    for t in range(100):#100
        viewer.render(env.render(mode='rgb_array'))
        action = env.action_space.sample()

        # Sleep makes the actions visible for users
        time.sleep(1)
        observation, reward, done, info = env.step(action)

        print(ACTION_LOOKUP[action], reward, done, info)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            viewer.render(env.render(mode='rgb_array'))
            break

    env.close()

time.sleep(10)
