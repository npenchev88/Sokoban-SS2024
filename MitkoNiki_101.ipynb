# %% [markdown]
# ### OLD code

# %%
import gym
import gym_sokoban
import pyglet
import time
from stable_baselines3 import PPO

# %%
## Custom rendering setup if gym's rendering is not available
class Viewer:
    def __init__(self, width, height):
        self.window = pyglet.window.Window(width, height)

    def render(self, image):
        self.window.clear()
        pyglet.image.ImageData(image.shape[1], image.shape[0], 'RGB', image.tobytes(), pitch=image.shape[1]*-3).blit(0, 0)
        self.window.flip()

# %%
env = gym.make('Sokoban-small-v1')
env.reset()

# %%
viewer = Viewer(160, 160)  # Adjust the size according to your environment

# %%
ACTION_LOOKUP = env.unwrapped.get_action_lookup()
# print("Created environment: {}".format('Sokoban-v2'))
#
for i_episode in range(1):#20
    # observation = env.reset()

    for t in range(100):#100
        viewer.render(env.render(mode='rgb_array'))
        action = env.action_space.sample()

        # Sleep makes the actions visible for users
        time.sleep(1)
        observation, reward, done, info = env.step(action)

        print(ACTION_LOOKUP[action], reward, done, info)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            viewer.render(env.render(mode='rgb_array'))
            break

    env.close()

time.sleep(10)

# %% [markdown]
# ### OLD v2

# %%
import gym
import gym_sokoban
import pyglet
from pyglet import clock
import numpy as np
import time

## Custom rendering setup if gym's rendering is not available
class Viewer:
    def __init__(self, width, height):
        self.window = pyglet.window.Window(width, height)
        self.image = None
        self.window.on_draw = self.on_draw

    def render(self, image):
        self.image = pyglet.image.ImageData(image.shape[1], image.shape[0], 'RGB', image.tobytes(), pitch=image.shape[1] * -3)
        self.window.dispatch_event('on_draw')

    def on_draw(self):
        if self.image:
            self.window.clear()
            self.image.blit(0, 0)

            

env = gym.make('Sokoban-small-v1')
env.reset()

viewer = Viewer(160, 160)  # Adjust the size according to your environment



ACTION_LOOKUP = env.unwrapped.get_action_lookup()
# print("Created environment: {}".format('Sokoban-v2'))
#
for i_episode in range(1):#20
    # observation = env.reset()

    for t in range(100):#100
        viewer.render(env.render(mode='rgb_array'))
        action = env.action_space.sample()

        # Sleep makes the actions visible for users
        time.sleep(1)
        observation, reward, done, info = env.step(action)

        print(ACTION_LOOKUP[action], reward, done, info)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            viewer.render(env.render(mode='rgb_array'))
            break

    env.close()

time.sleep(10)

# %% [markdown]
# ### ChatGPT generated

# %%
import gym
import gym_sokoban
import pyglet
from pyglet import clock
import numpy as np
import time

## Custom rendering setup if gym's rendering is not available
class Viewer:
    def __init__(self, width, height):
        self.window = pyglet.window.Window(width, height)
        self.image = None
        self.window.on_draw = self.on_draw

    def render(self, image):
        self.image = pyglet.image.ImageData(image.shape[1], image.shape[0], 'RGB', image.tobytes(), pitch=image.shape[1] * -3)
        self.window.dispatch_event('on_draw')

    def on_draw(self):
        if self.image:
            self.window.clear()
            self.image.blit(0, 0)

env = gym.make('Sokoban-small-v1')
env.reset()

viewer = Viewer(160, 160)  # Adjust the size according to your environment

ACTION_LOOKUP = env.unwrapped.get_action_lookup()

# Define episode and timestep parameters
num_episodes = 1
timesteps_per_episode = 100

def update_environment(dt):
    global num_episodes, timesteps_per_episode

    for i_episode in range(num_episodes):
        env.reset()
        for t in range(timesteps_per_episode):
            image = env.render(mode='rgb_array')
            viewer.render(image)
            action = env.action_space.sample()

            # Sleep to make the actions visible for users
            time.sleep(1)
            observation, reward, done, info = env.step(action)

            print(ACTION_LOOKUP[action], reward, done, info)
            if done:
                print(f"Episode finished after {t + 1} timesteps")
                viewer.render(env.render(mode='rgb_array'))
                break

        env.close()

    pyglet.app.exit()  # Stop the Pyglet event loop after finishing all episodes

# Schedule the update_environment function to run once at the start
clock.schedule_once(update_environment, 0)

pyglet.clock.schedule_interval(lambda dt: viewer.on_draw(), 1/60.0)  # Schedule the viewer update at 60Hz
pyglet.app.run()  # Run the Pyglet event loop

# Optional sleep to see the last frame before the script ends
time.sleep(10)

# %% [markdown]
# ### Working

# %%
import gym
import gym_sokoban
import pyglet
from pyglet import clock
import numpy as np

## Custom rendering setup if gym's rendering is not available
class Viewer:
    def __init__(self, width, height):
        self.window = pyglet.window.Window(width, height)
        self.image = None
        self.window.on_draw = self.on_draw

    def render(self, image):
        self.image = pyglet.image.ImageData(image.shape[1], image.shape[0], 'RGB', image.tobytes(), pitch=image.shape[1] * -3)
        self.window.dispatch_event('on_draw')

    def on_draw(self):
        if self.image:
            self.window.clear()
            self.image.blit(0, 0)

env = gym.make('Sokoban-small-v1')
env.reset()

viewer = Viewer(160, 160)  # Adjust the size according to your environment

ACTION_LOOKUP = env.unwrapped.get_action_lookup()

# Define episode and timestep parameters
num_episodes = 1
timesteps_per_episode = 100

current_episode = 0
current_timestep = 0

def update_environment(dt):
    global current_episode, current_timestep, num_episodes, timesteps_per_episode

    if current_episode < num_episodes:
        if current_timestep < timesteps_per_episode:
            action = env.action_space.sample()
            observation, reward, done, info = env.step(action)
            image = env.render(mode='rgb_array')
            viewer.render(image)

            print(ACTION_LOOKUP[action], reward, done, info)

            if done:
                print(f"Episode finished after {current_timestep + 1} timesteps")
                current_timestep = 0
                current_episode += 1
                env.reset()
            else:
                current_timestep += 1
        else:
            current_episode += 1
            current_timestep = 0
            env.reset()
    else:
        print("All episodes finished. Closing window.")
        pyglet.app.exit()  # Stop the Pyglet event loop after finishing all episodes

# Increase the frequency to match rendering needs (e.g., 60Hz)
clock.schedule_interval(update_environment, 1/60.0)

pyglet.app.run()

# %% [markdown]
# ### Working

# %%
import gym
import gym_sokoban
import pyglet
from pyglet import clock
import numpy as np

## Custom rendering setup if gym's rendering is not available
class Viewer:
    def __init__(self, width, height):
        self.window = pyglet.window.Window(width, height)
        self.image = None
        self.window.on_draw = self.on_draw

    def render(self, image):
        self.image = pyglet.image.ImageData(image.shape[1], image.shape[0], 'RGB', image.tobytes(), pitch=image.shape[1] * -3)
        self.window.dispatch_event('on_draw')

    def on_draw(self):
        if self.image:
            self.window.clear()
            self.image.blit(0, 0)

env = gym.make('Sokoban-small-v1')
env.reset()

# print("Room Fixed")
# print(env.room_fixed)
# print(type(env.room_fixed))
# print(env.room_fixed.shape)
# print()
# print(env.room_state)
# print()
# print(env.box_mapping)
# print()


viewer = Viewer(160, 160)  # Adjust the size according to your environment

ACTION_LOOKUP = env.unwrapped.get_action_lookup()

# Define episode and timestep parameters
num_episodes = 10
timesteps_per_episode = 100

current_episode = 0
current_timestep = 0

def update_environment(dt):
    global current_episode, current_timestep, num_episodes, timesteps_per_episode

    if current_episode < num_episodes:
        if current_timestep < timesteps_per_episode:
            # RANDOM ACTION
            action = env.action_space.sample()
            observation, reward, done, info = env.step(action)
            image = env.render(mode='rgb_array')
            viewer.render(image)

            print(ACTION_LOOKUP[action], reward, done, info)

            if done:
                print(f"Episode finished after {current_timestep + 1} timesteps")
                current_timestep = 0
                current_episode += 1
                env.reset()
            else:
                current_timestep += 1
        else:
            current_episode += 1
            current_timestep = 0
            env.reset()
    else:
        print("All episodes finished. Closing window.")
        viewer.window.close()  # Close the Pyglet window explicitly

# Increase the frequency to match rendering needs (e.g., 60Hz)
clock.schedule_interval(update_environment, 1/60.0)

pyglet.app.run()
# Out:
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': False, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': False, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': False, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': False, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': True}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': False, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push right 0.9 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': True}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': True}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# push right 0.9 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': True}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': True}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': True}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': True}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': False, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': False, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': True}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': False, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push right 0.9 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': True}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': True}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': True}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': True}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': True}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': False, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': True}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# ...
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': True}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': True}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': True}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': False, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': False, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': False, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': True}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': False, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': False, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push down -0.1 False {'action.name': 'push down', 'action.moved_player': True, 'action.moved_box': False}
# move left -0.1 False {'action.name': 'move left', 'action.moved_player': False, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': False, 'action.moved_box': False}
# move up -0.1 False {'action.name': 'move up', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# no operation -0.1 False {'action.name': 'no operation', 'action.moved_player': False, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': False, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push left -0.1 False {'action.name': 'push left', 'action.moved_player': True, 'action.moved_box': False}
# push right -0.1 False {'action.name': 'push right', 'action.moved_player': True, 'action.moved_box': False}
# move down -0.1 False {'action.name': 'move down', 'action.moved_player': False, 'action.moved_box': False}
# move right -0.1 False {'action.name': 'move right', 'action.moved_player': True, 'action.moved_box': False}
# push up -0.1 False {'action.name': 'push up', 'action.moved_player': False, 'action.moved_box': False}
# All episodes finished. Closing window.
# All episodes finished. Closing window.
# All episodes finished. Closing window.

# %% [markdown]
# ### Try to record a video

# %%
import gym
import gym_sokoban
import pyglet
from pyglet import clock
import numpy as np
import cv2

## Custom rendering setup if gym's rendering is not available
class Viewer:
    def __init__(self, width, height):
        self.window = pyglet.window.Window(width, height)
        self.image = None
        self.window.on_draw = self.on_draw

    def render(self, image):
        self.image = pyglet.image.ImageData(image.shape[1], image.shape[0], 'RGB', image.tobytes(), pitch=image.shape[1] * -3)
        self.window.dispatch_event('on_draw')

    def on_draw(self):
        if self.image:
            self.window.clear()
            self.image.blit(0, 0)

env = gym.make('Sokoban-small-v1')
env.reset()

viewer = Viewer(160, 160)  # Adjust the size according to your environment

ACTION_LOOKUP = env.unwrapped.get_action_lookup()

# Define episode and timestep parameters
num_episodes = 1
timesteps_per_episode = 100

current_episode = 0
current_timestep = 0

# Video recording parameters
video_filename = 'sokoban_gameplay.mp4'
fps = 30.0

# Initialize video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = None

def update_environment(dt):
    global current_episode, current_timestep, num_episodes, timesteps_per_episode, out

    if current_episode < num_episodes:
        if current_timestep < timesteps_per_episode:
            action = env.action_space.sample()
            observation, reward, done, info = env.step(action)
            image = env.render(mode='rgb_array')
            viewer.render(image)

            print(ACTION_LOOKUP[action], reward, done, info)

            if done:
                print(f"Episode finished after {current_timestep + 1} timesteps")
                current_timestep = 0
                current_episode += 1
                env.reset()
            else:
                current_timestep += 1
        else:
            current_episode += 1
            current_timestep = 0
            env.reset()
    else:
        print("All episodes finished. Closing window and saving video.")
        viewer.window.close()  # Close the Pyglet window explicitly
        out.release()  # Release the video writer

def record_frame(dt):
    global out

    # Capture the current frame from Pyglet window
    frame = pyglet.image.get_buffer_manager().get_color_buffer().get_image_data()

    # Convert frame to OpenCV format (numpy array)
    data = frame.get_data('RGB', frame.width * 3)
    arr = np.frombuffer(data, dtype=np.uint8)
    arr = arr.reshape((frame.height, frame.width, 3))

    # Convert RGB to BGR (OpenCV uses BGR)
    bgr_frame = cv2.cvtColor(arr, cv2.COLOR_RGB2BGR)

    # Initialize video writer if not already initialized
    if out is None:
        out = cv2.VideoWriter(video_filename, fourcc, fps, (frame.width, frame.height))

    # Write frame to video
    out.write(bgr_frame)

# Schedule the frame recording function to run at a fixed interval (e.g., 30 fps)
clock.schedule_interval(record_frame, 1/fps)

# Increase the frequency to match rendering needs (e.g., 60Hz)
clock.schedule_interval(update_environment, 1/60.0)

pyglet.app.run()

# %% [markdown]
# ### Other

# %%
import gym
import gym_sokoban
import pyglet
import time
from stable_baselines3 import PPO
import threading

## Custom rendering setup if gym's rendering is not available
class Viewer:
    def __init__(self, width, height):
        self.window = pyglet.window.Window(width, height)
        self.image = None

    def render(self, image):
        self.image = pyglet.image.ImageData(image.shape[1], image.shape[0], 'RGB', image.tobytes(), pitch=image.shape[1] * -3)
        self.window.clear()
        self.image.blit(0, 0)
        self.window.flip()

    def update(self, dt):
        if self.image:
            self.window.clear()
            self.image.blit(0, 0)
            self.window.flip()

def run_pyglet_app():
    pyglet.clock.schedule_interval(viewer.update, 1/60.0)  # Schedule the viewer update at 60Hz
    pyglet.app.run()  # Run the Pyglet event loop

env = gym.make('Sokoban-small-v1')
env.reset()

viewer = Viewer(160, 160)  # Adjust the size according to your environment

# Start the Pyglet event loop in a separate thread
pyglet_thread = threading.Thread(target=run_pyglet_app)
pyglet_thread.daemon = True
pyglet_thread.start()

ACTION_LOOKUP = env.unwrapped.get_action_lookup()

for i_episode in range(1):  # Run for one episode
    for t in range(100):  # Run for 100 timesteps
        image = env.render(mode='rgb_array')
        viewer.render(image)
        action = env.action_space.sample()

        # Sleep to make the actions visible for users
        time.sleep(1)
        observation, reward, done, info = env.step(action)

        print(ACTION_LOOKUP[action], reward, done, info)
        if done:
            print("Episode finished after {} timesteps".format(t + 1))
            viewer.render(env.render(mode='rgb_array'))
            break

    env.close()

# Keep the program running for a while to observe the output
time.sleep(10)

# %%
import gym
import gym_sokoban
import pyglet
import time
import threading

## Custom rendering setup if gym's rendering is not available
class Viewer:
    def __init__(self, width, height):
        self.window = pyglet.window.Window(width, height)
        self.image = None

    def render(self, image):
        self.image = pyglet.image.ImageData(image.shape[1], image.shape[0], 'RGB', image.tobytes(), pitch=image.shape[1] * -3)
        self.window.clear()
        self.image.blit(0, 0)
        self.window.flip()

    def update(self, dt):
        if self.image:
            self.window.clear()
            self.image.blit(0, 0)
            self.window.flip()

def run_pyglet_app(event_loop):
    pyglet.clock.schedule_interval(viewer.update, 1/60.0)  # Schedule the viewer update at 60Hz
    event_loop.run()  # Run the Pyglet event loop

env = gym.make('Sokoban-small-v1')
env.reset()

viewer = Viewer(160, 160)  # Adjust the size according to your environment
event_loop = pyglet.app.EventLoop()

# Start the Pyglet event loop in a separate thread
pyglet_thread = threading.Thread(target=run_pyglet_app, args=(event_loop,))
pyglet_thread.daemon = True
pyglet_thread.start()

ACTION_LOOKUP = env.unwrapped.get_action_lookup()

for i_episode in range(1):  # Run for one episode
    for t in range(100):  # Run for 100 timesteps
        image = env.render(mode='rgb_array')
        viewer.render(image)
        action = env.action_space.sample()

        # Sleep to make the actions visible for users
        time.sleep(1)
        observation, reward, done, info = env.step(action)

        print(ACTION_LOOKUP[action], reward, done, info)
        if done:
            print("Episode finished after {} timesteps".format(t + 1))
            viewer.render(env.render(mode='rgb_array'))
            break

    env.close()

# Keep the program running for a while to observe the output
time.sleep(10)
event_loop.exit()  # Stop the Pyglet event loop

# %%
ACTION_LOOKUP = env.unwrapped.get_action_lookup()
# print("Created environment: {}".format('Sokoban-v2'))
#
for i_episode in range(1):#20
    # observation = env.reset()

    for t in range(100):#100
        viewer.render(env.render(mode='rgb_array'))
        action = env.action_space.sample()

        # Sleep makes the actions visible for users
        time.sleep(1)
        observation, reward, done, info = env.step(action)

        print(ACTION_LOOKUP[action], reward, done, info)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            viewer.render(env.render(mode='rgb_array'))
            break

    env.close()

time.sleep(10)

# %%
import gym
import gym_sokoban
import pyglet
from pyglet import clock
import numpy as np

## Custom rendering setup if gym's rendering is not available
class Viewer:
    def __init__(self, width, height):
        self.window = pyglet.window.Window(width, height)
        self.image = None
        self.window.on_draw = self.on_draw

    def render(self, image):
        self.image = pyglet.image.ImageData(image.shape[1], image.shape[0], 'RGB', image.tobytes(), pitch=image.shape[1] * -3)
        self.window.dispatch_event('on_draw')

    def on_draw(self):
        if self.image:
            self.window.clear()
            self.image.blit(0, 0)

env = gym.make('Sokoban-small-v1')
env.reset()

viewer = Viewer(160, 160)  # Adjust the size according to your environment

ACTION_LOOKUP = env.unwrapped.get_action_lookup()
done = False

def update_environment(dt):
    global done
    if not done:
        image = env.render(mode='rgb_array')
        viewer.render(image)
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
        print(ACTION_LOOKUP[action], reward, done, info)
        if done:
            print("Episode finished")
            env.reset()
            done = False

# Schedule the update_environment function to run at a fixed interval
clock.schedule_interval(update_environment, 1)  # Update every second (adjust as needed)

pyglet.clock.schedule_interval(lambda dt: viewer.on_draw(), 1/60.0)  # Schedule the viewer update at 60Hz
pyglet.app.run()  # Run the Pyglet event loop

# %%
import gym
import gym_sokoban
import pyglet
import time
from stable_baselines3 import PPO

## Custom rendering setup if gym's rendering is not available
class Viewer:
    def __init__(self, width, height):
        self.window = pyglet.window.Window(width, height)

    def render(self, image):
        self.window.clear()
        pyglet.image.ImageData(image.shape[1], image.shape[0], 'RGB', image.tobytes(), pitch=image.shape[1]*-3).blit(0, 0)
        self.window.flip()
        
        
env = gym.make('Sokoban-small-v1')
env.reset()


viewer = Viewer(160, 160)  # Adjust the size according to your environment


ACTION_LOOKUP = env.unwrapped.get_action_lookup()
# print("Created environment: {}".format('Sokoban-v2'))
#
for i_episode in range(1):#20
    # observation = env.reset()

    for t in range(100):#100
        viewer.render(env.render(mode='rgb_array'))
        action = env.action_space.sample()

        # Sleep makes the actions visible for users
        time.sleep(1)
        observation, reward, done, info = env.step(action)

        print(ACTION_LOOKUP[action], reward, done, info)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            viewer.render(env.render(mode='rgb_array'))
            break

    env.close()

time.sleep(10)
