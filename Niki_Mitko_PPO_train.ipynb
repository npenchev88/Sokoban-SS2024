# %%
import gym
import gym_sokoban
import pyglet
import time
import numpy as np
from stable_baselines3 import PPO

# %%
## Custom rendering setup if gym's rendering is not available
class Viewer:
    def __init__(self, width, height):
        self.window = pyglet.window.Window(width, height)

    def render(self, image):
        self.window.clear()
        pyglet.image.ImageData(image.shape[1], image.shape[0], 'RGB', image.tobytes(), pitch=image.shape[1]*-3).blit(0, 0)
        self.window.flip()

# %%
env = gym.make('Sokoban-small-v1')
# model = PPO('MlpPolicy', env, verbose=1)

# # Train the model
# model.learn(total_timesteps=100000)
# # Save the model to a file
# model.save("ppo_test")

loaded_model = PPO.load("ppo_test")

env.reset()
# Out:
# array([[[176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0],
#         ...,
#         [176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0]],
#
#        [[176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0],
#         ...,
#         [176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0]],
#
#        [[176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0],
#         ...,
#         [176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0]],
#
#        ...,
#
#        [[176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0],
#         ...,
#         [176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0]],
#
#        [[176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0],
#         ...,
#         [176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0]],
#
#        [[176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0],
#         ...,
#         [176,  61,   0],
#         [176,  61,   0],
#         [176,  61,   0]]], dtype=uint8)

# %%
viewer = Viewer(160, 160)  # Adjust the size according to your environment

# %%
ACTION_LOOKUP = env.unwrapped.get_action_lookup()
# print("Created environment: {}".format('Sokoban-v2'))
#
for i_episode in range(1):#20
    # observation = env.reset()

    for t in range(100):#100
        viewer.render(env.render(mode='rgb_array'))
        # action = env.action_space.sample()
        action, _states = loaded_model.predict(obs, deterministic=True)
        print(ACTION_LOOKUP, _states)
        action = int(action)  
        # Sleep makes the actions visible for users
        time.sleep(1)
        observation, reward, done, info = env.step(action)

        print(ACTION_LOOKUP[action], reward, done, _states, info)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            viewer.render(env.render(mode='rgb_array'))
            break

    env.close()

time.sleep(10)
# Out:
# /home/npenchev/.local/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:289: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# /home/npenchev/.local/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /home/npenchev/.local/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:225: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
# {0: 'no operation', 1: 'push up', 2: 'push down', 3: 'push left', 4: 'push right', 5: 'move up', 6: 'move down', 7: 'move left', 8: 'move right'} None
# push down -0.1 False None {'action.name': 'push down', 'action.moved_player': False, 'action.moved_box': False}
